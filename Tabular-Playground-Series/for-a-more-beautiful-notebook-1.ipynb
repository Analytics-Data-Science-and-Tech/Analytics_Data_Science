# %% [markdown]
# # Hello friends, I want to show you how we can make our work better in this "notebook". I'll do this by dividing it into 2 parts. The first part, that is, this work, will be a little more amateur than the second part. So let's start.

# %%
# Header 1
## Header 2
### Header 3
#### Header 4
##### Header 5
###### Header 6

<h1>Header 1</h1>
<h2>Header 2</h2>
<h3>Header 3</h3>
<h4>Header 4</h4>
<h5>Header 5</h5>
<h6>Header 6</h6>

# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4
# ##### Header 5
# ###### Header 6
#
# <h1>Header 1</h1>
# <h2>Header 2</h2>
# <h3>Header 3</h3>
# <h4>Header 4</h4>
# <h5>Header 5</h5>
# <h6>Header 6</h6>

# %%
**This is bold text**  
__This is bold text__
<strong>This is bold text</strong>

# %% [markdown]
# **This is bold text**
# __This is bold text__
#
# <strong>This is bold text</strong>

# %%
*This is italic text*  
_This is italic text_
<em>This is italic text</em>

# %% [markdown]
# *This is italic text*
# _This is italic text_
# <em>This is italic text</em>

# %%
***Bold and Italic***  
___Bold and Italic___
<strong><em> Bold and Italic </em></strong>

# %% [markdown]
# ***Bold and Italic***
# ___Bold and Italic___
# <strong><em> Bold and Italic </em></strong>

# %%
<u>Underline</u><br>

# %% [markdown]
# <u>Underline</u><br>

# %%
~~delete this text~~
<del>delete this text</del>

# %% [markdown]
# ~~delete this text~~
# <del>delete this text</del>

# %%
This is <span style="color:red">apple</span>    **color:blue|red|green|pink|yellow

# %% [markdown]
# This is <span style="color:red">apple</span>    **color:blue|red|green|pink|yellow

# %%
> <div class="alert alert-block alert-info">
<b>Tip:</b> Use blue boxes (alert-info) for tips and notes.</div>

# %% [markdown]
# > <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.</div>

# %%
> <div class="alert alert-block alert-warning">
<b>Example:</b> Use yellow boxes for examples that are not inside code cells, 
or use for mathematical formulas if needed. 
Typically also used to display warning messages.
</div>

# %% [markdown]
# > <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not inside code cells,
# or use for mathematical formulas if needed.
# Typically also used to display warning messages.
# </div>

# %%
> <div class="alert alert-block alert-success">
<b>Success:</b> This alert box indicates a successful or positive action.
</div>

# %% [markdown]
# > <div class="alert alert-block alert-success">
# <b>Success:</b> This alert box indicates a successful or positive action.
# </div>

# %%
> <div class="alert alert-block alert-danger">
<b>EXAMPLE:</b> Copy this entire line and paste it into the "markdown" section.
</div>

# %% [markdown]
# > <div class="alert alert-block alert-danger">
# <b>EXAMPLE:</b> Copy this entire line and paste it into the "markdown" section.
# </div>

# %%
<a href="https://google.com">https://www.linkedin.com/in/melike-dilekci-727224204/</a>

# %% [markdown]
# <a href="https://google.com">https://www.linkedin.com/in/melike-dilekci-727224204/</a>

# %%
<a id="table"></a>
<h1 style="background-color:lightgreen;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 15px 50px;">Table Of Content</h1>

 * [1. IMPORTING LIBRARIES](#1)
    
* [2. LOADING DATASET](#2)
  
* [3. EXPLORATORY SOME INFORMATION ABOUT DATASET](#3)

* [4. DATA VISUALIZATION](#4)

* [5. RESULT](#5)

* [6. AUTHOR MESSAGE](#6)


![](https://www.hareketligifler.net/data/media/388/cep-telefonu-hareketli-resim-0019.gif)

![](https://m.media-amazon.com/images/I/41o3lmgN-VL._SY344_BO1,204,203,200_QL70_ML2_.jpg)

# %% [markdown]
# <a id="table"></a>
# <h1 style="background-color:lightgreen;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 15px 50px;">Table Of Content</h1>
#
#  * [1. IMPORTING LIBRARIES](#1)
#
# * [2. LOADING DATASET](#2)
#
# * [3. EXPLORATORY SOME INFORMATION ABOUT DATASET](#3)
#
# * [4. DATA VISUALIZATION](#4)
#
# * [5. RESULT](#5)
#
# * [6. AUTHOR MESSAGE](#6)
#
#
# ![](https://www.hareketligifler.net/data/media/388/cep-telefonu-hareketli-resim-0019.gif)
#
# ![](https://m.media-amazon.com/images/I/41o3lmgN-VL._SY344_BO1,204,203,200_QL70_ML2_.jpg)

# %% [markdown]
# # ***Note that you can change the colors of the tables.***
# # ***just copy the image address for the image or gif or drag the gif or image from your computer to the "markdown" section.***

# %%
<a id="1"></a>
# <p style="padding:10px;background-color:lightgreen;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">IMPORTING LIBRARIES</p>

# %% [markdown]
# # ***To connect with above:***

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:cyan;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">IMPORTING LIBRARIES</p>

# %%
<a id="1"></a>
# <p style="padding:10px;background-color:cyan;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">IMPORTING LIBRARIES</p>

# %% [markdown]
# # You can adapt it by changing the place where it says 1 and the title, Now it's that simple to link.

# %% [markdown]
# # One more piece of advice from me :) If you want to stand out among the works, your headline should be striking. That's why you can put emojis related to the attention-grabbing subject in the title.

# %% [markdown]
# # Finally... 💭
#
# # Feel free to use this notebook as a reference when you work on a new notebook. I hope that this notebook helps all my fellow kagglers in some way.
#
# # I will keep updating this notebook ⏳
