# %%
pip install lightgbm xgboost catboost optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting lightgbm
#   Downloading lightgbm-3.3.5-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.9 MB/s eta 0:00:00:00:01
# Collecting xgboost
#   Downloading xgboost-1.7.4-py3-none-manylinux2014_x86_64.whl (193.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 MB 3.5 MB/s eta 0:00:0000:0100:01
# Collecting catboost
#   Downloading catboost-1.1.1-cp310-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 10.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: optuna in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from lightgbm) (1.22.4)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from lightgbm) (1.1.3)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from lightgbm) (1.9.3)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from catboost) (3.6.1)
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: plotly in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from catboost) (5.11.0)
# Requirement already satisfied: pandas>=0.24.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from catboost) (1.5.1)
# Requirement already satisfied: PyYAML in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (5.4.1)
# Requirement already satisfied: colorlog in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (6.7.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (1.4.42)
# Requirement already satisfied: alembic>=1.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (1.9.4)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (4.64.1)
# Requirement already satisfied: cmaes>=0.9.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (0.9.1)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (21.3)
# Requirement already satisfied: Mako in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas>=0.24.0->catboost) (2022.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn!=0.22.0->lightgbm) (1.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna) (1.1.3.post0)
# Requirement already satisfied: pillow>=6.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->catboost) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->catboost) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->catboost) (1.0.6)
# Requirement already satisfied: tenacity>=6.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from plotly->catboost) (8.1.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Installing collected packages: graphviz, xgboost, lightgbm, catboost
# Successfully installed catboost-1.1.1 graphviz-0.20.1 lightgbm-3.3.5 xgboost-1.7.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
import pandas as pd; pd.set_option('display.max_columns', 100)
import numpy as np

import matplotlib.pyplot as plt; plt.style.use('ggplot')
import seaborn as sns

from scipy.stats import rankdata
from sklearn.multiclass import OneVsRestClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold, train_test_split, GridSearchCV, StratifiedKFold, TimeSeriesSplit
from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

import optuna 

s3 = boto3.resource('s3')
bucket_name = 'analytics-data-science-competitions'
bucket = s3.Bucket(bucket_name)

file_key_1 = 'Tabular-Playground-Series/PS-S3/Ep7/train.csv'
file_key_2 = 'Tabular-Playground-Series/PS-S3/Ep7/test.csv'
file_key_3 = 'Tabular-Playground-Series/PS-S3/Ep7/sample_submission.csv'

bucket_object_1 = bucket.Object(file_key_1)
file_object_1 = bucket_object_1.get()
file_content_stream_1 = file_object_1.get('Body')

bucket_object_2 = bucket.Object(file_key_2)
file_object_2 = bucket_object_2.get()
file_content_stream_2 = file_object_2.get('Body')

bucket_object_3 = bucket.Object(file_key_3)
file_object_3 = bucket_object_3.get()
file_content_stream_3 = file_object_3.get('Body')

## Reading data files
train = pd.read_csv(file_content_stream_1)
test = pd.read_csv(file_content_stream_2)
submission = pd.read_csv(file_content_stream_3)

## Fixing dates (https://www.kaggle.com/competitions/playground-series-s3e7/discussion/386655)
train['arrival_year_month'] = pd.to_datetime(train['arrival_year'].astype(str) + train['arrival_month'].astype(str), format = '%Y%m')
test['arrival_year_month'] = pd.to_datetime(test['arrival_year'].astype(str) + test['arrival_month'].astype(str), format = '%Y%m')

train.loc[train.arrival_date > train.arrival_year_month.dt.days_in_month, 'arrival_date'] = train.arrival_year_month.dt.days_in_month
test.loc[test.arrival_date > test.arrival_year_month.dt.days_in_month, 'arrival_date'] = test.arrival_year_month.dt.days_in_month

train.drop(columns = 'arrival_year_month', inplace = True)
test.drop(columns = 'arrival_year_month', inplace = True)

train['low_price_flag'] = np.where(train['avg_price_per_room'] < 30, 1, 0)
train['segment_0'] = np.where(train['market_segment_type'] == 0, 1, 0)
train['segment_1'] = np.where(train['market_segment_type'] == 1, 1, 0)
train['total_guests'] = train['no_of_adults'] + train['no_of_children']
train['stay_length'] = train['no_of_weekend_nights'] + train['no_of_week_nights']
train['stay_during_weekend'] = np.where(train['no_of_weekend_nights'] > 0, 1, 0)
train['quarter_1'] = np.where(train['arrival_month'] <= 3, 1, 0)
train['quarter_2'] = np.where(((train['arrival_month'] >= 4) & (train['arrival_month'] <= 6)), 1, 0)
train['quarter_3'] = np.where(((train['arrival_month'] >= 7) & (train['arrival_month'] <= 9)), 1, 0)
train['quarter_4'] = np.where(train['arrival_month'] >= 10, 1, 0)
train['segment_0_feature_1'] = np.where(((train['market_segment_type'] == 0) & (train['lead_time'] <= 90)), 1, 0)
train['segment_0_feature_2'] = np.where(((train['market_segment_type'] == 0) & (train['avg_price_per_room'] > 98)), 1, 0)
train['segment_1_feature_1'] = np.where(((train['market_segment_type'] == 1) & (train['no_of_special_requests'] == 0)), 1, 0)
train['segment_1_feature_2'] = np.where(((train['market_segment_type'] == 1) & (train['no_of_special_requests'] > 0) & (train['lead_time'] <= 150)), 1, 0)
train['segment_0_year_flag'] = np.where(((train['market_segment_type'] == 0) & (train['arrival_year'] == 2018)), 1, 0)
train['segment_1_year_flag'] = np.where(((train['market_segment_type'] == 1) & (train['arrival_year'] == 2018)), 1, 0)
train['price_lead_time_flag'] = np.where(((train['avg_price_per_room'] > 100) & (train['lead_time'] > 150)), 1, 0)

test['low_price_flag'] = np.where(test['avg_price_per_room'] < 30, 1, 0)
test['segment_0'] = np.where(test['market_segment_type'] == 0, 1, 0)
test['segment_1'] = np.where(test['market_segment_type'] == 1, 1, 0)
test['total_guests'] = test['no_of_adults'] + test['no_of_children']
test['stay_length'] = test['no_of_weekend_nights'] + test['no_of_week_nights']
test['stay_during_weekend'] = np.where(test['no_of_weekend_nights'] > 0, 1, 0)
test['quarter_1'] = np.where(test['arrival_month'] <= 3, 1, 0)
test['quarter_2'] = np.where(((test['arrival_month'] >= 4) & (test['arrival_month'] <= 6)), 1, 0)
test['quarter_3'] = np.where(((test['arrival_month'] >= 7) & (test['arrival_month'] <= 9)), 1, 0)
test['quarter_4'] = np.where(test['arrival_month'] >= 10, 1, 0)
test['segment_0_feature_1'] = np.where(((test['market_segment_type'] == 0) & (test['lead_time'] <= 90)), 1, 0)
test['segment_0_feature_2'] = np.where(((test['market_segment_type'] == 0) & (test['avg_price_per_room'] > 98)), 1, 0)
test['segment_1_feature_1'] = np.where(((test['market_segment_type'] == 1) & (test['no_of_special_requests'] == 0)), 1, 0)
test['segment_1_feature_2'] = np.where(((test['market_segment_type'] == 1) & (test['no_of_special_requests'] > 0) & (test['lead_time'] <= 150)), 1, 0)
test['segment_0_year_flag'] = np.where(((test['market_segment_type'] == 0) & (test['arrival_year'] == 2018)), 1, 0)
test['segment_1_year_flag'] = np.where(((test['market_segment_type'] == 1) & (test['arrival_year'] == 2018)), 1, 0)
test['price_lead_time_flag'] = np.where(((test['avg_price_per_room'] > 100) & (test['lead_time'] > 150)), 1, 0)

# %%
train_lgb = train.copy()
test_lgb = test.copy()

# X = train_lgb[['avg_price_per_room', 'lead_time', 'segment_0', 'segment_1', 'total_guests', 'stay_length', 'stay_during_weekend', 'quarter_1', 'quarter_2', 'quarter_3', 'quarter_4', 'segment_0_feature_1', 'segment_0_feature_2', 'segment_1_feature_1', 'segment_1_feature_2', 'segment_0_year_flag', 'segment_1_year_flag']]
# Y = train_lgb['booking_status']

# test_lgb = test_lgb[['avg_price_per_room', 'lead_time', 'segment_0', 'segment_1', 'total_guests', 'stay_length', 'stay_during_weekend', 'quarter_1', 'quarter_2', 'quarter_3', 'quarter_4', 'segment_0_feature_1', 'segment_0_feature_2', 'segment_1_feature_1', 'segment_1_feature_2', 'segment_0_year_flag', 'segment_1_year_flag']]

X = train_lgb[['avg_price_per_room', 'lead_time', 'total_guests', 'stay_length', 'arrival_year', 'arrival_month', 'arrival_date', 'market_segment_type', 'repeated_guest', 'no_of_special_requests']]
# X = train_lgb[['avg_price_per_room', 'lead_time', 'total_guests', 'stay_length', 'segment_0_feature_1', 'segment_1_feature_1']]
Y = train_lgb['booking_status']

test_lgb = test_lgb[['avg_price_per_room', 'lead_time', 'total_guests', 'stay_length', 'arrival_year', 'arrival_month', 'arrival_date', 'market_segment_type', 'repeated_guest', 'no_of_special_requests']]

# %% [markdown]
# # Optuna Optimization

# %%
class Objective:

    def __init__(self, seed):
        # Hold this implementation specific arguments as the fields of the class.
        self.seed = seed

    def __call__(self, trial):
        
        ## Parameters to be evaluated
        params = dict(l2_regularization = trial.suggest_float('l2_regularization', 0.01, 10.0, log = True),
                      early_stopping = trial.suggest_categorical('early_stopping', ['False']),
                      learning_rate = trial.suggest_float('learning_rate', 0.001, 1, log = True),
                      max_iter = trial.suggest_categorical('max_iter', [1000]),
                      max_depth = trial.suggest_int('max_depth', 2, 15),
                      max_bins = trial.suggest_int('max_bins', 100, 255),
                      min_samples_leaf = trial.suggest_int('min_samples_leaf', 20, 100),
                      max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 20, 100)
                     )
    
        scores = []
        
        skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = self.seed)
        
        for train_idx, valid_idx in skf.split(X, Y):

            X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
            Y_train , Y_valid = Y.iloc[train_idx] , Y.iloc[valid_idx]
        
            hist_md = HistGradientBoostingClassifier(**params).fit(X_train, Y_train)
            
            preds_valid = hist_md.predict_proba(X_valid)[:, 1]

            score = roc_auc_score(Y_valid, preds_valid)
            scores.append(score)
            
        return np.mean(scores)

## Defining number of runs and seed
RUNS = 50
SEED = 42
N_TRIALS = 50

# Execute an optimization
study = optuna.create_study(direction = 'maximize')
study.optimize(Objective(SEED), n_trials = N_TRIALS)
# Out:
# [I 2023-02-19 03:01:52,548] A new study created in memory with name: no-name-8086ad01-a008-49d2-9a12-af95beec4e6b
# [I 2023-02-19 03:01:56,770] Trial 0 finished with value: 0.8894343029331593 and parameters: {'l2_regularization': 4.956455555688623, 'early_stopping': 'False', 'learning_rate': 0.40280947334278666, 'max_iter': 1000, 'max_depth': 12, 'max_bins': 169, 'min_samples_leaf': 68, 'max_leaf_nodes': 51}. Best is trial 0 with value: 0.8894343029331593.
# [I 2023-02-19 03:03:15,078] Trial 1 finished with value: 0.8819341997220377 and parameters: {'l2_regularization': 0.010619164823281877, 'early_stopping': 'False', 'learning_rate': 0.002007566687239226, 'max_iter': 1000, 'max_depth': 9, 'max_bins': 110, 'min_samples_leaf': 57, 'max_leaf_nodes': 90}. Best is trial 0 with value: 0.8894343029331593.
# [I 2023-02-19 03:03:47,598] Trial 2 finished with value: 0.890133406074366 and parameters: {'l2_regularization': 0.01792288309397063, 'early_stopping': 'False', 'learning_rate': 0.01708215572033562, 'max_iter': 1000, 'max_depth': 8, 'max_bins': 115, 'min_samples_leaf': 79, 'max_leaf_nodes': 100}. Best is trial 2 with value: 0.890133406074366.
# [I 2023-02-19 03:03:50,365] Trial 3 finished with value: 0.8918578838961851 and parameters: {'l2_regularization': 0.06059998007889617, 'early_stopping': 'False', 'learning_rate': 0.27514016296029437, 'max_iter': 1000, 'max_depth': 4, 'max_bins': 253, 'min_samples_leaf': 72, 'max_leaf_nodes': 40}. Best is trial 3 with value: 0.8918578838961851.
# [I 2023-02-19 03:05:01,377] Trial 4 finished with value: 0.8821539654765814 and parameters: {'l2_regularization': 0.798876413484769, 'early_stopping': 'False', 'learning_rate': 0.002110663908447077, 'max_iter': 1000, 'max_depth': 13, 'max_bins': 160, 'min_samples_leaf': 90, 'max_leaf_nodes': 60}. Best is trial 3 with value: 0.8918578838961851.
# [I 2023-02-19 03:05:09,836] Trial 5 finished with value: 0.8916477372858062 and parameters: {'l2_regularization': 0.4880400724138768, 'early_stopping': 'False', 'learning_rate': 0.0716922885464178, 'max_iter': 1000, 'max_depth': 12, 'max_bins': 179, 'min_samples_leaf': 69, 'max_leaf_nodes': 48}. Best is trial 3 with value: 0.8918578838961851.
# [I 2023-02-19 03:05:14,785] Trial 6 finished with value: 0.8894479528688072 and parameters: {'l2_regularization': 0.025285947356893327, 'early_stopping': 'False', 'learning_rate': 0.1365269539883875, 'max_iter': 1000, 'max_depth': 5, 'max_bins': 101, 'min_samples_leaf': 59, 'max_leaf_nodes': 77}. Best is trial 3 with value: 0.8918578838961851.
# [I 2023-02-19 03:05:15,993] Trial 7 finished with value: 0.8818167534451533 and parameters: {'l2_regularization': 0.059599609187502935, 'early_stopping': 'False', 'learning_rate': 0.8667032462017551, 'max_iter': 1000, 'max_depth': 6, 'max_bins': 117, 'min_samples_leaf': 71, 'max_leaf_nodes': 84}. Best is trial 3 with value: 0.8918578838961851.
# [I 2023-02-19 03:05:45,779] Trial 8 finished with value: 0.8738994398651279 and parameters: {'l2_regularization': 0.09814149566377565, 'early_stopping': 'False', 'learning_rate': 0.002063215049528216, 'max_iter': 1000, 'max_depth': 5, 'max_bins': 206, 'min_samples_leaf': 99, 'max_leaf_nodes': 82}. Best is trial 3 with value: 0.8918578838961851.
# [I 2023-02-19 03:05:52,198] Trial 9 finished with value: 0.8921559460506805 and parameters: {'l2_regularization': 3.21665430148425, 'early_stopping': 'False', 'learning_rate': 0.08775516444086578, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 198, 'min_samples_leaf': 69, 'max_leaf_nodes': 46}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:06:09,928] Trial 10 finished with value: 0.8911357327634212 and parameters: {'l2_regularization': 9.379916118795443, 'early_stopping': 'False', 'learning_rate': 0.028123472479429517, 'max_iter': 1000, 'max_depth': 15, 'max_bins': 225, 'min_samples_leaf': 31, 'max_leaf_nodes': 22}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:06:15,905] Trial 11 finished with value: 0.8908223014130048 and parameters: {'l2_regularization': 1.8304277053691238, 'early_stopping': 'False', 'learning_rate': 0.15387842152997547, 'max_iter': 1000, 'max_depth': 3, 'max_bins': 250, 'min_samples_leaf': 43, 'max_leaf_nodes': 31}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:06:19,448] Trial 12 finished with value: 0.8883024740468437 and parameters: {'l2_regularization': 0.13877889566511872, 'early_stopping': 'False', 'learning_rate': 0.3226334922831342, 'max_iter': 1000, 'max_depth': 2, 'max_bins': 253, 'min_samples_leaf': 50, 'max_leaf_nodes': 37}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:06:28,305] Trial 13 finished with value: 0.8921360066534249 and parameters: {'l2_regularization': 0.23237551268990106, 'early_stopping': 'False', 'learning_rate': 0.06262350565058517, 'max_iter': 1000, 'max_depth': 9, 'max_bins': 213, 'min_samples_leaf': 83, 'max_leaf_nodes': 44}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:06:42,226] Trial 14 finished with value: 0.8918794794929047 and parameters: {'l2_regularization': 0.25649269941044633, 'early_stopping': 'False', 'learning_rate': 0.044684665096398665, 'max_iter': 1000, 'max_depth': 9, 'max_bins': 200, 'min_samples_leaf': 86, 'max_leaf_nodes': 67}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:07:19,983] Trial 15 finished with value: 0.8912590597963275 and parameters: {'l2_regularization': 1.5131511443450139, 'early_stopping': 'False', 'learning_rate': 0.013698704860242154, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 223, 'min_samples_leaf': 98, 'max_leaf_nodes': 56}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:07:28,060] Trial 16 finished with value: 0.8914458335526734 and parameters: {'l2_regularization': 0.4327103802108114, 'early_stopping': 'False', 'learning_rate': 0.07752004795600707, 'max_iter': 1000, 'max_depth': 7, 'max_bins': 149, 'min_samples_leaf': 85, 'max_leaf_nodes': 43}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:08:34,457] Trial 17 finished with value: 0.8917992873541672 and parameters: {'l2_regularization': 2.7318825356382646, 'early_stopping': 'False', 'learning_rate': 0.008577540072992409, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 191, 'min_samples_leaf': 26, 'max_leaf_nodes': 67}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:08:46,857] Trial 18 finished with value: 0.8918235802653254 and parameters: {'l2_regularization': 0.8240740973744837, 'early_stopping': 'False', 'learning_rate': 0.04307746190332039, 'max_iter': 1000, 'max_depth': 15, 'max_bins': 224, 'min_samples_leaf': 78, 'max_leaf_nodes': 27}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:08:52,289] Trial 19 finished with value: 0.890557928459315 and parameters: {'l2_regularization': 0.24984042976130813, 'early_stopping': 'False', 'learning_rate': 0.10807100978998166, 'max_iter': 1000, 'max_depth': 13, 'max_bins': 144, 'min_samples_leaf': 43, 'max_leaf_nodes': 62}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:09:33,930] Trial 20 finished with value: 0.888116742714492 and parameters: {'l2_regularization': 5.484215325768808, 'early_stopping': 'False', 'learning_rate': 0.006244809649242698, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 212, 'min_samples_leaf': 63, 'max_leaf_nodes': 35}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:09:45,856] Trial 21 finished with value: 0.8916634860402489 and parameters: {'l2_regularization': 0.23827659798946352, 'early_stopping': 'False', 'learning_rate': 0.044631244182366255, 'max_iter': 1000, 'max_depth': 8, 'max_bins': 185, 'min_samples_leaf': 87, 'max_leaf_nodes': 71}. Best is trial 9 with value: 0.8921559460506805.
# [I 2023-02-19 03:09:56,529] Trial 22 finished with value: 0.8922458685073262 and parameters: {'l2_regularization': 0.18794808896298576, 'early_stopping': 'False', 'learning_rate': 0.04796177905043246, 'max_iter': 1000, 'max_depth': 9, 'max_bins': 196, 'min_samples_leaf': 78, 'max_leaf_nodes': 48}. Best is trial 22 with value: 0.8922458685073262.
# [I 2023-02-19 03:10:15,336] Trial 23 finished with value: 0.8926552907697116 and parameters: {'l2_regularization': 0.13837771555320347, 'early_stopping': 'False', 'learning_rate': 0.02556595359916955, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 236, 'min_samples_leaf': 78, 'max_leaf_nodes': 48}. Best is trial 23 with value: 0.8926552907697116.
# [I 2023-02-19 03:10:41,457] Trial 24 finished with value: 0.8926582715723231 and parameters: {'l2_regularization': 0.13009955009469068, 'early_stopping': 'False', 'learning_rate': 0.020660011434821986, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 232, 'min_samples_leaf': 75, 'max_leaf_nodes': 54}. Best is trial 24 with value: 0.8926582715723231.
# [I 2023-02-19 03:11:08,648] Trial 25 finished with value: 0.8914465022597934 and parameters: {'l2_regularization': 0.12603353691020863, 'early_stopping': 'False', 'learning_rate': 0.02025446502723375, 'max_iter': 1000, 'max_depth': 7, 'max_bins': 231, 'min_samples_leaf': 93, 'max_leaf_nodes': 54}. Best is trial 24 with value: 0.8926582715723231.
# [I 2023-02-19 03:11:25,182] Trial 26 finished with value: 0.8917717459581553 and parameters: {'l2_regularization': 0.067131961677441, 'early_stopping': 'False', 'learning_rate': 0.03358456851978756, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 239, 'min_samples_leaf': 73, 'max_leaf_nodes': 58}. Best is trial 24 with value: 0.8926582715723231.
# [I 2023-02-19 03:12:03,541] Trial 27 finished with value: 0.8902256145148989 and parameters: {'l2_regularization': 0.1359645222394098, 'early_stopping': 'False', 'learning_rate': 0.008540736964637745, 'max_iter': 1000, 'max_depth': 13, 'max_bins': 240, 'min_samples_leaf': 78, 'max_leaf_nodes': 33}. Best is trial 24 with value: 0.8926582715723231.
# [I 2023-02-19 03:12:28,979] Trial 28 finished with value: 0.8923108020692258 and parameters: {'l2_regularization': 0.3990999679416792, 'early_stopping': 'False', 'learning_rate': 0.02259642501720208, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 237, 'min_samples_leaf': 63, 'max_leaf_nodes': 50}. Best is trial 24 with value: 0.8926582715723231.
# [I 2023-02-19 03:12:53,010] Trial 29 finished with value: 0.8919894025985776 and parameters: {'l2_regularization': 0.45312965505221137, 'early_stopping': 'False', 'learning_rate': 0.021551263217474755, 'max_iter': 1000, 'max_depth': 12, 'max_bins': 239, 'min_samples_leaf': 65, 'max_leaf_nodes': 52}. Best is trial 24 with value: 0.8926582715723231.
# [I 2023-02-19 03:13:15,493] Trial 30 finished with value: 0.8916952010345657 and parameters: {'l2_regularization': 0.041133590349690205, 'early_stopping': 'False', 'learning_rate': 0.026727879463863114, 'max_iter': 1000, 'max_depth': 14, 'max_bins': 213, 'min_samples_leaf': 53, 'max_leaf_nodes': 64}. Best is trial 24 with value: 0.8926582715723231.
# [I 2023-02-19 03:13:50,380] Trial 31 finished with value: 0.8911735871093975 and parameters: {'l2_regularization': 0.1766932042504994, 'early_stopping': 'False', 'learning_rate': 0.01432110370241944, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 169, 'min_samples_leaf': 76, 'max_leaf_nodes': 50}. Best is trial 24 with value: 0.8926582715723231.
# [I 2023-02-19 03:14:11,126] Trial 32 finished with value: 0.8919942144009397 and parameters: {'l2_regularization': 0.10163888761042235, 'early_stopping': 'False', 'learning_rate': 0.03766204984533058, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 233, 'min_samples_leaf': 65, 'max_leaf_nodes': 51}. Best is trial 24 with value: 0.8926582715723231.
# [I 2023-02-19 03:14:31,103] Trial 33 finished with value: 0.8926616214205918 and parameters: {'l2_regularization': 0.353760021392382, 'early_stopping': 'False', 'learning_rate': 0.024446062687597626, 'max_iter': 1000, 'max_depth': 12, 'max_bins': 246, 'min_samples_leaf': 82, 'max_leaf_nodes': 42}. Best is trial 33 with value: 0.8926616214205918.
# [I 2023-02-19 03:15:05,442] Trial 34 finished with value: 0.8919879514515678 and parameters: {'l2_regularization': 0.35589731774856054, 'early_stopping': 'False', 'learning_rate': 0.013829444585954052, 'max_iter': 1000, 'max_depth': 12, 'max_bins': 246, 'min_samples_leaf': 82, 'max_leaf_nodes': 40}. Best is trial 33 with value: 0.8926616214205918.
# [I 2023-02-19 03:15:29,939] Trial 35 finished with value: 0.89273246033196 and parameters: {'l2_regularization': 0.633684996940886, 'early_stopping': 'False', 'learning_rate': 0.0254690768949852, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 244, 'min_samples_leaf': 94, 'max_leaf_nodes': 39}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:16:03,114] Trial 36 finished with value: 0.8910655051898303 and parameters: {'l2_regularization': 0.6726497806710272, 'early_stopping': 'False', 'learning_rate': 0.010988982528303123, 'max_iter': 1000, 'max_depth': 14, 'max_bins': 255, 'min_samples_leaf': 90, 'max_leaf_nodes': 27}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:16:47,745] Trial 37 finished with value: 0.88736791977054 and parameters: {'l2_regularization': 0.6880746256164815, 'early_stopping': 'False', 'learning_rate': 0.00464065612631582, 'max_iter': 1000, 'max_depth': 12, 'max_bins': 245, 'min_samples_leaf': 95, 'max_leaf_nodes': 39}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:17:19,950] Trial 38 finished with value: 0.8916339174554686 and parameters: {'l2_regularization': 0.17316597010442816, 'early_stopping': 'False', 'learning_rate': 0.01816819272585067, 'max_iter': 1000, 'max_depth': 13, 'max_bins': 221, 'min_samples_leaf': 91, 'max_leaf_nodes': 43}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:17:41,661] Trial 39 finished with value: 0.8916326152867619 and parameters: {'l2_regularization': 0.32067003971169933, 'early_stopping': 'False', 'learning_rate': 0.028214135605112673, 'max_iter': 1000, 'max_depth': 8, 'max_bins': 230, 'min_samples_leaf': 81, 'max_leaf_nodes': 98}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:17:50,517] Trial 40 finished with value: 0.8925225087630008 and parameters: {'l2_regularization': 0.0781319164384983, 'early_stopping': 'False', 'learning_rate': 0.05666251383755255, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 245, 'min_samples_leaf': 75, 'max_leaf_nodes': 58}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:18:01,127] Trial 41 finished with value: 0.8927258971350038 and parameters: {'l2_regularization': 0.0921589823345134, 'early_stopping': 'False', 'learning_rate': 0.05688077553277336, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 243, 'min_samples_leaf': 74, 'max_leaf_nodes': 57}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:18:17,909] Trial 42 finished with value: 0.8920880544157479 and parameters: {'l2_regularization': 0.04639676620198636, 'early_stopping': 'False', 'learning_rate': 0.02696745218459481, 'max_iter': 1000, 'max_depth': 12, 'max_bins': 218, 'min_samples_leaf': 72, 'max_leaf_nodes': 45}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:18:30,562] Trial 43 finished with value: 0.8915727979120834 and parameters: {'l2_regularization': 0.09248726545913064, 'early_stopping': 'False', 'learning_rate': 0.035301322312030106, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 230, 'min_samples_leaf': 88, 'max_leaf_nodes': 55}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:19:00,408] Trial 44 finished with value: 0.8918368787973883 and parameters: {'l2_regularization': 0.11382805838929627, 'early_stopping': 'False', 'learning_rate': 0.01686162019936533, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 247, 'min_samples_leaf': 95, 'max_leaf_nodes': 75}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:19:07,655] Trial 45 finished with value: 0.8926522696294338 and parameters: {'l2_regularization': 0.02660325809882656, 'early_stopping': 'False', 'learning_rate': 0.07244318140958204, 'max_iter': 1000, 'max_depth': 14, 'max_bins': 255, 'min_samples_leaf': 100, 'max_leaf_nodes': 40}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:19:17,005] Trial 46 finished with value: 0.8921233745713352 and parameters: {'l2_regularization': 0.16985286950402306, 'early_stopping': 'False', 'learning_rate': 0.05246507183665334, 'max_iter': 1000, 'max_depth': 12, 'max_bins': 208, 'min_samples_leaf': 69, 'max_leaf_nodes': 61}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:19:20,880] Trial 47 finished with value: 0.8914284903452458 and parameters: {'l2_regularization': 0.0768194115964837, 'early_stopping': 'False', 'learning_rate': 0.2024975849503709, 'max_iter': 1000, 'max_depth': 13, 'max_bins': 235, 'min_samples_leaf': 82, 'max_leaf_nodes': 31}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:19:33,385] Trial 48 finished with value: 0.8915841150894395 and parameters: {'l2_regularization': 0.29152763977617685, 'early_stopping': 'False', 'learning_rate': 0.0323998823871062, 'max_iter': 1000, 'max_depth': 9, 'max_bins': 242, 'min_samples_leaf': 58, 'max_leaf_nodes': 46}. Best is trial 35 with value: 0.89273246033196.
# [I 2023-02-19 03:19:37,836] Trial 49 finished with value: 0.8904353710140102 and parameters: {'l2_regularization': 0.5068790329763333, 'early_stopping': 'False', 'learning_rate': 0.09897672400253676, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 123, 'min_samples_leaf': 85, 'max_leaf_nodes': 36}. Best is trial 35 with value: 0.89273246033196.

# %%
study.best_trial.values
# Out:
# [0.89273246033196]

# %%
study.best_trial.params
# Out:
# {'l2_regularization': 0.633684996940886,
#  'early_stopping': 'False',
#  'learning_rate': 0.0254690768949852,
#  'max_iter': 1000,
#  'max_depth': 11,
#  'max_bins': 244,
#  'min_samples_leaf': 94,
#  'max_leaf_nodes': 39}

# %% [markdown]
# # Cross Validation

# %%
hist_cv_scores, roc_auc_scores, hist_imp = list(), list(), list()
preds = list()

## Running 5 times CV
for i in range(5):
    
    skf = StratifiedKFold(n_splits = 5, random_state = 42, shuffle = True)
    
    for train_ix, test_ix in skf.split(X, Y):
        
        ## Splitting the data 
        X_train, X_test = X.iloc[train_ix], X.iloc[test_ix]
        Y_train, Y_test = Y.iloc[train_ix], Y.iloc[test_ix]
                
        ## Building RF model
        hist_md = HistGradientBoostingClassifier(l2_regularization = 0.633684996940886,
                                                early_stopping = 'False',
                                                learning_rate = 0.0254690768949852,
                                                max_iter = 1000,
                                                max_depth = 11,
                                                max_bins = 244,
                                                min_samples_leaf = 94,
                                                max_leaf_nodes = 39).fit(X_train, Y_train)
#         hist_imp.append(hist_md.feature_importances_)
        
        ## Predicting on X_test and test
        Hist_pred_1 = hist_md.predict_proba(X_test)[:, 1]
        Hist_pred_2 = hist_md.predict_proba(test_lgb)[:, 1]
        
        ## Computing roc-auc score
        roc_auc_scores.append(roc_auc_score(Y_test, Hist_pred_1))
        preds.append(Hist_pred_2)

    hist_cv_scores.append(np.mean(roc_auc_scores))
    
Hist_cv_score = np.mean(hist_cv_scores)    
print('The average oof roc-auc score over 5-folds (run 5 times) is:', Hist_cv_score)
# Out:
# The average oof roc-auc score over 5-folds (run 5 times) is: 0.8918208721252749

# %%
Hist_preds_test = pd.DataFrame(preds).apply(np.mean, axis = 0)

submission['booking_status'] = Hist_preds_test
submission.head()
# Out:
#       id  booking_status
# 0  42100        0.100813
# 1  42101        0.058563
# 2  42102        0.325709
# 3  42103        0.102554
# 4  42104        0.621270

# %%
submission.to_csv('Hist_10_features_optuna_submission.csv', index = False)
