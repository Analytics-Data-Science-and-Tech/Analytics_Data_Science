# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.multiclass import OneVsRestClassifier
import tensorflow as tf

train = pd.read_csv('train.csv')
train = train.fillna(0)

test = pd.read_csv('test.csv')
test = test.fillna(0)

test_id = test['id']
test = test.drop(columns = ['id', 'keyword', 'location', 'text', 'clean_tweet'], axis = 1)

## Defining input and target variables 
X = train.drop(columns = ['id', 'keyword', 'location', 'text', 'clean_tweet', 'target'], axis = 1)
Y = train['target']

## Splitting the data 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

## Scaling the data 
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
test = scaler.fit_transform(test)

## Defining model 
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(10, input_dim = 65, activation = 'relu'),
#         tf.keras.layers.Dense(10, activation = 'relu'),
        tf.keras.layers.Dense(2, activation = 'softmax')
])

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

## Fitting model 
model.fit(X_train, tf.keras.utils.to_categorical(Y_train, num_classes = 2), epochs = 50, batch_size = 32, validation_data = (X_test, tf.keras.utils.to_categorical(Y_test, num_classes = 2)))

## Predicting on train and test
nn_train_pred = model.predict(X_train)[:, 1]
nn_test_pred = model.predict(test)[:, 1]


def precision_recall_cutoff(Y_test, Y_pred):
    
    ## Computing the precision recall curve
    precision, recall, thresholds = precision_recall_curve(Y_test, Y_pred)
    
    ## Creating the precision-recall data-frame
    precision_recall = pd.DataFrame({'precision': precision[:-1], 'recall': recall[:-1], 'cutoff': thresholds})
    
    ## Finding the optimal cutoff (closest to precision = 1, recall = 1)
    precision_recall['1_minus_precision'] = 1 - precision_recall['precision']
    precision_recall['1_minus_recall'] = 1 - precision_recall['recall']
    precision_recall['Distance_to_perfect_model'] = np.sqrt(precision_recall['1_minus_precision']**2 + precision_recall['1_minus_recall']**2)
    
    ## Sorting based on Distance 
    precision_recall = precision_recall.sort_values(by = 'Distance_to_perfect_model').reset_index(drop = True)
        
    return precision_recall['cutoff'][0]

opt_cutoff = precision_recall_cutoff(Y_train, nn_train_pred)
print('The optimal cutoff is', opt_cutoff)

## Changing likelihoods to labels
nn_test_label = np.where(nn_test_pred < opt_cutoff, 0, 1)

## Creating data-frame for submission
data_out = pd.DataFrame({'id': test_id, 'target': nn_test_label})
# data_out.to_csv('network_submission_3.csv', index = False)
# Out:
# Epoch 1/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.6790 - accuracy: 0.5757 - val_loss: 0.6757 - val_accuracy: 0.5693
# Epoch 2/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.6541 - accuracy: 0.6213 - val_loss: 0.6342 - val_accuracy: 0.6717
# Epoch 3/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.6096 - accuracy: 0.6722 - val_loss: 0.5956 - val_accuracy: 0.6888
# Epoch 4/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5885 - accuracy: 0.6833 - val_loss: 0.5873 - val_accuracy: 0.6907
# Epoch 5/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5797 - accuracy: 0.6890 - val_loss: 0.5845 - val_accuracy: 0.7012
# Epoch 6/50
# 191/191 [==============================] - 0s 3ms/step - loss: 0.5748 - accuracy: 0.6875 - val_loss: 0.5815 - val_accuracy: 0.7118
# Epoch 7/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5706 - accuracy: 0.6941 - val_loss: 0.5802 - val_accuracy: 0.7098
# Epoch 8/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5674 - accuracy: 0.6957 - val_loss: 0.5843 - val_accuracy: 0.7091
# Epoch 9/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5643 - accuracy: 0.6982 - val_loss: 0.5825 - val_accuracy: 0.7012
# Epoch 10/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5618 - accuracy: 0.7021 - val_loss: 0.5791 - val_accuracy: 0.7085
# Epoch 11/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5602 - accuracy: 0.7123 - val_loss: 0.5789 - val_accuracy: 0.7085
# Epoch 12/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.5568 - accuracy: 0.7076 - val_loss: 0.5757 - val_accuracy: 0.7006
# Epoch 13/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5551 - accuracy: 0.7092 - val_loss: 0.5782 - val_accuracy: 0.7150
# Epoch 14/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5537 - accuracy: 0.7154 - val_loss: 0.5759 - val_accuracy: 0.7078
# Epoch 15/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5499 - accuracy: 0.7163 - val_loss: 0.5767 - val_accuracy: 0.7058
# Epoch 16/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5498 - accuracy: 0.7166 - val_loss: 0.5781 - val_accuracy: 0.7118
# Epoch 17/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5466 - accuracy: 0.7153 - val_loss: 0.5790 - val_accuracy: 0.7118
# Epoch 18/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5458 - accuracy: 0.7181 - val_loss: 0.5774 - val_accuracy: 0.7032
# Epoch 19/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5445 - accuracy: 0.7197 - val_loss: 0.5799 - val_accuracy: 0.7045
# Epoch 20/50
# 191/191 [==============================] - 0s 3ms/step - loss: 0.5437 - accuracy: 0.7194 - val_loss: 0.5794 - val_accuracy: 0.7058
# Epoch 21/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5431 - accuracy: 0.7190 - val_loss: 0.5777 - val_accuracy: 0.7032
# Epoch 22/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5413 - accuracy: 0.7166 - val_loss: 0.5790 - val_accuracy: 0.7052
# Epoch 23/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5394 - accuracy: 0.7250 - val_loss: 0.5799 - val_accuracy: 0.7072
# Epoch 24/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5402 - accuracy: 0.7232 - val_loss: 0.5792 - val_accuracy: 0.6993
# Epoch 25/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.5391 - accuracy: 0.7232 - val_loss: 0.5800 - val_accuracy: 0.7012
# Epoch 26/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5375 - accuracy: 0.7273 - val_loss: 0.5804 - val_accuracy: 0.7032
# Epoch 27/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5376 - accuracy: 0.7274 - val_loss: 0.5810 - val_accuracy: 0.7111
# Epoch 28/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5373 - accuracy: 0.7264 - val_loss: 0.5823 - val_accuracy: 0.7026
# Epoch 29/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.5353 - accuracy: 0.7251 - val_loss: 0.5830 - val_accuracy: 0.7026
# Epoch 30/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5365 - accuracy: 0.7235 - val_loss: 0.5840 - val_accuracy: 0.7026
# Epoch 31/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.5358 - accuracy: 0.7276 - val_loss: 0.5806 - val_accuracy: 0.6986
# Epoch 32/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5339 - accuracy: 0.7243 - val_loss: 0.5901 - val_accuracy: 0.7052
# Epoch 33/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5357 - accuracy: 0.7250 - val_loss: 0.5828 - val_accuracy: 0.7026
# Epoch 34/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5332 - accuracy: 0.7286 - val_loss: 0.5841 - val_accuracy: 0.7032
# Epoch 35/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5315 - accuracy: 0.7284 - val_loss: 0.5869 - val_accuracy: 0.7012
# Epoch 36/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5329 - accuracy: 0.7281 - val_loss: 0.5876 - val_accuracy: 0.6973
# Epoch 37/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5327 - accuracy: 0.7268 - val_loss: 0.5835 - val_accuracy: 0.7006
# Epoch 38/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.5319 - accuracy: 0.7289 - val_loss: 0.5809 - val_accuracy: 0.6980
# Epoch 39/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.5305 - accuracy: 0.7282 - val_loss: 0.5806 - val_accuracy: 0.7019
# Epoch 40/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.5303 - accuracy: 0.7250 - val_loss: 0.5821 - val_accuracy: 0.6953
# Epoch 41/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.5306 - accuracy: 0.7307 - val_loss: 0.5812 - val_accuracy: 0.6973
# Epoch 42/50
# 191/191 [==============================] - 0s 3ms/step - loss: 0.5294 - accuracy: 0.7250 - val_loss: 0.5799 - val_accuracy: 0.7012
# Epoch 43/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5292 - accuracy: 0.7287 - val_loss: 0.5816 - val_accuracy: 0.6947
# Epoch 44/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5293 - accuracy: 0.7292 - val_loss: 0.5847 - val_accuracy: 0.6973
# Epoch 45/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5285 - accuracy: 0.7302 - val_loss: 0.5836 - val_accuracy: 0.6993
# Epoch 46/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5268 - accuracy: 0.7327 - val_loss: 0.5832 - val_accuracy: 0.6973
# Epoch 47/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.5284 - accuracy: 0.7282 - val_loss: 0.5836 - val_accuracy: 0.6986
# Epoch 48/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5280 - accuracy: 0.7282 - val_loss: 0.5835 - val_accuracy: 0.6953
# Epoch 49/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.5279 - accuracy: 0.7276 - val_loss: 0.5832 - val_accuracy: 0.6953
# Epoch 50/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.5263 - accuracy: 0.7310 - val_loss: 0.5829 - val_accuracy: 0.6993
# The optimal cutoff is 0.34716642

# %%
data_out.to_csv('network_submission_3.csv', index = False)

# %%
data_out['target'].value_counts() / data_out.shape[0]
# Out:
# 1    0.517009
# 0    0.482991
# Name: target, dtype: float64

# %%
data_out['target'].value_counts() / data_out.shape[0]
# Out:
# 1    0.581673
# 0    0.418327
# Name: target, dtype: float64

# %%
Y.value_counts() / Y.shape[0]
# Out:
# 0    0.57034
# 1    0.42966
# Name: target, dtype: float64

# %%
X_train.shape
# Out:
# (6090, 65)

# %%
nn_pred
# Out:
# array([[0.7194805 , 0.28051952],
#        [0.6584695 , 0.3415305 ],
#        [0.6979774 , 0.3020226 ],
#        ...,
#        [0.35780114, 0.64219886],
#        [0.62765753, 0.37234244],
#        [0.5311666 , 0.46883336]], dtype=float32)

# %%
def precision_recall_cutoff(Y_test, Y_pred):
    
    ## Computing the precision recall curve
    precision, recall, thresholds = precision_recall_curve(Y_test, Y_pred)
    
    ## Creating the precision-recall data-frame
    precision_recall = pd.DataFrame({'precision': precision[:-1], 'recall': recall[:-1], 'cutoff': thresholds})
    
    ## Finding the optimal cutoff (closest to precision = 1, recall = 1)
    precision_recall['1_minus_precision'] = 1 - precision_recall['precision']
    precision_recall['1_minus_recall'] = 1 - precision_recall['recall']
    precision_recall['Distance_to_perfect_model'] = np.sqrt(precision_recall['1_minus_precision']**2 + precision_recall['1_minus_recall']**2)
    
    ## Sorting based on Distance 
    precision_recall = precision_recall.sort_values(by = 'Distance_to_perfect_model').reset_index(drop = True)
        
    return precision_recall['cutoff'][0]


logit_pred = logit_md.predict_(X)[:, 1]
opt_cutoff = precision_recall_cutoff(Y, logit_pred)
print('The optimal cutoff is', opt_cutoff)

## Predicting on test 
logit_test_pred = logit_md.predict_proba(test.drop(columns = ['id', 'keyword', 'text'], axis = 1))[:, 1]

## Changing likelihoods to labels
logit_test_label = np.where(logit_test_pred < opt_cutoff, 0, 1)

## Creating data-frame for submission
data_out = pd.DataFrame({'id': test['id'], 'target': logit_test_label})
data_out.to_csv('Logistic_submission_1.csv', index = False)

# %%
Y_test
# Out:
# 7092    0
# 145     1
# 6006    1
# 6937    0
# 2419    1
#        ..
# 2112    0
# 4728    0
# 5594    1
# 5142    0
# 6986    0
# Name: target, Length: 1523, dtype: int64

# %%
test.head()
# Out:
#    id keyword location                                               text  \
# 0   0       0        0                 Just happened a terrible car crash
# 1   2       0        0  Heard about #earthquake is different cities, s...
# 2   3       0        0  there is a forest fire at spot pond, geese are...
# 3   9       0        0           Apocalypse lighting. #Spokane #wildfires
# 4  11       0        0      Typhoon Soudelor kills 28 in China and Taiwan
#
#                                          clean_tweet  subjectivity  negative  \
# 0                        happened terrible car crash          1.00         1
# 1          heard different cities stay safe everyone          0.55         0
# 2  forest fire spot pond geese fleeing across str...          0.00         0
# 3                                apocalypse lighting          0.00         0
# 4             typhoon soudelor kills 28 china taiwan          0.00         0
#
#    neutral  positive  char_count  word_count  sent_count  capital_char_count  \
# 0        0         0          34           6           1                   1
# 1        0         1          64           9           1                   1
# 2        1         0          96          19           1                   1
# 3        1         0          40           4           2                   2
# 4        1         0          45           8           1                   4
#
#    capital_word_count  stopword_count  unique_word_count  avg_wordlength  \
# 0                   0               1                  6        5.666667
# 1                   0               2                  9        7.111111
# 2                   1              10                 19        5.052632
# 3                   0               0                  4       10.000000
# 4                   0               2                  8        5.625000
#
#    avg_sentlength  unique_vs_words  stopwords_vs_words
# 0             6.0              1.0            0.166667
# 1             9.0              1.0            0.222222
# 2            19.0              1.0            0.526316
# 3             2.0              1.0            0.000000
# 4             8.0              1.0            0.250000
