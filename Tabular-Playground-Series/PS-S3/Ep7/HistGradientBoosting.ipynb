# %%
pip install lightgbm xgboost catboost optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting lightgbm
#   Downloading lightgbm-3.3.5-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.9 MB/s eta 0:00:00:00:01
# Collecting xgboost
#   Downloading xgboost-1.7.4-py3-none-manylinux2014_x86_64.whl (193.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 MB 3.5 MB/s eta 0:00:0000:0100:01
# Collecting catboost
#   Downloading catboost-1.1.1-cp310-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 10.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: optuna in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from lightgbm) (1.22.4)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from lightgbm) (1.1.3)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from lightgbm) (1.9.3)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from catboost) (3.6.1)
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: plotly in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from catboost) (5.11.0)
# Requirement already satisfied: pandas>=0.24.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from catboost) (1.5.1)
# Requirement already satisfied: PyYAML in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (5.4.1)
# Requirement already satisfied: colorlog in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (6.7.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (1.4.42)
# Requirement already satisfied: alembic>=1.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (1.9.4)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (4.64.1)
# Requirement already satisfied: cmaes>=0.9.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (0.9.1)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from optuna) (21.3)
# Requirement already satisfied: Mako in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas>=0.24.0->catboost) (2022.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn!=0.22.0->lightgbm) (1.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna) (1.1.3.post0)
# Requirement already satisfied: pillow>=6.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->catboost) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->catboost) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib->catboost) (1.0.6)
# Requirement already satisfied: tenacity>=6.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from plotly->catboost) (8.1.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Installing collected packages: graphviz, xgboost, lightgbm, catboost
# Successfully installed catboost-1.1.1 graphviz-0.20.1 lightgbm-3.3.5 xgboost-1.7.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
import pandas as pd; pd.set_option('display.max_columns', 100)
import numpy as np

import matplotlib.pyplot as plt; plt.style.use('ggplot')
import seaborn as sns

from scipy.stats import rankdata
from sklearn.multiclass import OneVsRestClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold, train_test_split, GridSearchCV, StratifiedKFold, TimeSeriesSplit
from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

import optuna 

s3 = boto3.resource('s3')
bucket_name = 'analytics-data-science-competitions'
bucket = s3.Bucket(bucket_name)

file_key_1 = 'Tabular-Playground-Series/PS-S3/Ep7/train.csv'
file_key_2 = 'Tabular-Playground-Series/PS-S3/Ep7/test.csv'
file_key_3 = 'Tabular-Playground-Series/PS-S3/Ep7/sample_submission.csv'

bucket_object_1 = bucket.Object(file_key_1)
file_object_1 = bucket_object_1.get()
file_content_stream_1 = file_object_1.get('Body')

bucket_object_2 = bucket.Object(file_key_2)
file_object_2 = bucket_object_2.get()
file_content_stream_2 = file_object_2.get('Body')

bucket_object_3 = bucket.Object(file_key_3)
file_object_3 = bucket_object_3.get()
file_content_stream_3 = file_object_3.get('Body')

## Reading data files
train = pd.read_csv(file_content_stream_1)
test = pd.read_csv(file_content_stream_2)
submission = pd.read_csv(file_content_stream_3)

## Fixing dates (https://www.kaggle.com/competitions/playground-series-s3e7/discussion/386655)
train['arrival_year_month'] = pd.to_datetime(train['arrival_year'].astype(str) + train['arrival_month'].astype(str), format = '%Y%m')
test['arrival_year_month'] = pd.to_datetime(test['arrival_year'].astype(str) + test['arrival_month'].astype(str), format = '%Y%m')

train.loc[train.arrival_date > train.arrival_year_month.dt.days_in_month, 'arrival_date'] = train.arrival_year_month.dt.days_in_month
test.loc[test.arrival_date > test.arrival_year_month.dt.days_in_month, 'arrival_date'] = test.arrival_year_month.dt.days_in_month

train.drop(columns = 'arrival_year_month', inplace = True)
test.drop(columns = 'arrival_year_month', inplace = True)

train['low_price_flag'] = np.where(train['avg_price_per_room'] < 30, 1, 0)
train['segment_0'] = np.where(train['market_segment_type'] == 0, 1, 0)
train['segment_1'] = np.where(train['market_segment_type'] == 1, 1, 0)
train['total_guests'] = train['no_of_adults'] + train['no_of_children']
train['stay_length'] = train['no_of_weekend_nights'] + train['no_of_week_nights']
train['stay_during_weekend'] = np.where(train['no_of_weekend_nights'] > 0, 1, 0)
train['quarter_1'] = np.where(train['arrival_month'] <= 3, 1, 0)
train['quarter_2'] = np.where(((train['arrival_month'] >= 4) & (train['arrival_month'] <= 6)), 1, 0)
train['quarter_3'] = np.where(((train['arrival_month'] >= 7) & (train['arrival_month'] <= 9)), 1, 0)
train['quarter_4'] = np.where(train['arrival_month'] >= 10, 1, 0)
train['segment_0_feature_1'] = np.where(((train['market_segment_type'] == 0) & (train['lead_time'] <= 90)), 1, 0)
train['segment_0_feature_2'] = np.where(((train['market_segment_type'] == 0) & (train['avg_price_per_room'] > 98)), 1, 0)
train['segment_1_feature_1'] = np.where(((train['market_segment_type'] == 1) & (train['no_of_special_requests'] == 0)), 1, 0)
train['segment_1_feature_2'] = np.where(((train['market_segment_type'] == 1) & (train['no_of_special_requests'] > 0) & (train['lead_time'] <= 150)), 1, 0)
train['segment_0_year_flag'] = np.where(((train['market_segment_type'] == 0) & (train['arrival_year'] == 2018)), 1, 0)
train['segment_1_year_flag'] = np.where(((train['market_segment_type'] == 1) & (train['arrival_year'] == 2018)), 1, 0)
train['price_lead_time_flag'] = np.where(((train['avg_price_per_room'] > 100) & (train['lead_time'] > 150)), 1, 0)

test['low_price_flag'] = np.where(test['avg_price_per_room'] < 30, 1, 0)
test['segment_0'] = np.where(test['market_segment_type'] == 0, 1, 0)
test['segment_1'] = np.where(test['market_segment_type'] == 1, 1, 0)
test['total_guests'] = test['no_of_adults'] + test['no_of_children']
test['stay_length'] = test['no_of_weekend_nights'] + test['no_of_week_nights']
test['stay_during_weekend'] = np.where(test['no_of_weekend_nights'] > 0, 1, 0)
test['quarter_1'] = np.where(test['arrival_month'] <= 3, 1, 0)
test['quarter_2'] = np.where(((test['arrival_month'] >= 4) & (test['arrival_month'] <= 6)), 1, 0)
test['quarter_3'] = np.where(((test['arrival_month'] >= 7) & (test['arrival_month'] <= 9)), 1, 0)
test['quarter_4'] = np.where(test['arrival_month'] >= 10, 1, 0)
test['segment_0_feature_1'] = np.where(((test['market_segment_type'] == 0) & (test['lead_time'] <= 90)), 1, 0)
test['segment_0_feature_2'] = np.where(((test['market_segment_type'] == 0) & (test['avg_price_per_room'] > 98)), 1, 0)
test['segment_1_feature_1'] = np.where(((test['market_segment_type'] == 1) & (test['no_of_special_requests'] == 0)), 1, 0)
test['segment_1_feature_2'] = np.where(((test['market_segment_type'] == 1) & (test['no_of_special_requests'] > 0) & (test['lead_time'] <= 150)), 1, 0)
test['segment_0_year_flag'] = np.where(((test['market_segment_type'] == 0) & (test['arrival_year'] == 2018)), 1, 0)
test['segment_1_year_flag'] = np.where(((test['market_segment_type'] == 1) & (test['arrival_year'] == 2018)), 1, 0)
test['price_lead_time_flag'] = np.where(((test['avg_price_per_room'] > 100) & (test['lead_time'] > 150)), 1, 0)

# %%
train_lgb = train.copy()
test_lgb = test.copy()

# X = train_lgb[['avg_price_per_room', 'lead_time', 'segment_0', 'segment_1', 'total_guests', 'stay_length', 'stay_during_weekend', 'quarter_1', 'quarter_2', 'quarter_3', 'quarter_4', 'segment_0_feature_1', 'segment_0_feature_2', 'segment_1_feature_1', 'segment_1_feature_2', 'segment_0_year_flag', 'segment_1_year_flag']]
# Y = train_lgb['booking_status']

# test_lgb = test_lgb[['avg_price_per_room', 'lead_time', 'segment_0', 'segment_1', 'total_guests', 'stay_length', 'stay_during_weekend', 'quarter_1', 'quarter_2', 'quarter_3', 'quarter_4', 'segment_0_feature_1', 'segment_0_feature_2', 'segment_1_feature_1', 'segment_1_feature_2', 'segment_0_year_flag', 'segment_1_year_flag']]

X = train_lgb[['avg_price_per_room', 'lead_time', 'total_guests', 'stay_length', 'segment_0_feature_1', 'segment_1_feature_1']]
Y = train_lgb['booking_status']

test_lgb = test_lgb[['avg_price_per_room', 'lead_time', 'total_guests', 'stay_length', 'segment_0_feature_1', 'segment_1_feature_1']]

# %% [markdown]
# # Optuna Optimization

# %%
class Objective:

    def __init__(self, seed):
        # Hold this implementation specific arguments as the fields of the class.
        self.seed = seed

    def __call__(self, trial):
        
        ## Parameters to be evaluated
        params = dict(l2_regularization = trial.suggest_float('l2_regularization', 0.01, 10.0, log = True),
                      early_stopping = trial.suggest_categorical('early_stopping', ['False']),
                      learning_rate = trial.suggest_float('learning_rate', 0.001, 1, log = True),
                      max_iter = trial.suggest_categorical('max_iter', [1000]),
                      max_depth = trial.suggest_int('max_depth', 2, 15),
                      max_bins = trial.suggest_int('max_bins', 100, 255),
                      min_samples_leaf = trial.suggest_int('min_samples_leaf', 20, 100),
                      max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 20, 100)
                     )
    
        scores = []
        
        skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = self.seed)
        
        for train_idx, valid_idx in skf.split(X, Y):

            X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
            Y_train , Y_valid = Y.iloc[train_idx] , Y.iloc[valid_idx]
        
            hist_md = HistGradientBoostingClassifier(**params).fit(X_train, Y_train)
            
            preds_valid = hist_md.predict_proba(X_valid)[:, 1]

            score = roc_auc_score(Y_valid, preds_valid)
            scores.append(score)
            
        return np.mean(scores)

## Defining number of runs and seed
RUNS = 50
SEED = 42
N_TRIALS = 50

# Execute an optimization
study = optuna.create_study(direction = 'maximize')
study.optimize(Objective(SEED), n_trials = N_TRIALS)
# Out:
# [I 2023-02-18 15:21:01,663] A new study created in memory with name: no-name-956c9170-ac2f-4c06-a5f8-77d5e20c21ab
# [I 2023-02-18 15:21:03,557] Trial 0 finished with value: 0.8677807448117303 and parameters: {'l2_regularization': 0.015957154212727625, 'early_stopping': 'False', 'learning_rate': 0.7932478415590914, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 223, 'min_samples_leaf': 63, 'max_leaf_nodes': 90}. Best is trial 0 with value: 0.8677807448117303.
# [I 2023-02-18 15:21:07,412] Trial 1 finished with value: 0.8746975715968887 and parameters: {'l2_regularization': 0.3397925073338393, 'early_stopping': 'False', 'learning_rate': 0.2340203110742252, 'max_iter': 1000, 'max_depth': 3, 'max_bins': 248, 'min_samples_leaf': 26, 'max_leaf_nodes': 95}. Best is trial 1 with value: 0.8746975715968887.
# [I 2023-02-18 15:21:08,607] Trial 2 finished with value: 0.8728647919874366 and parameters: {'l2_regularization': 0.8487185581704367, 'early_stopping': 'False', 'learning_rate': 0.6243007647184092, 'max_iter': 1000, 'max_depth': 4, 'max_bins': 184, 'min_samples_leaf': 30, 'max_leaf_nodes': 30}. Best is trial 1 with value: 0.8746975715968887.
# [I 2023-02-18 15:21:49,008] Trial 3 finished with value: 0.8655855485491891 and parameters: {'l2_regularization': 0.7551003916776489, 'early_stopping': 'False', 'learning_rate': 0.003200612921332129, 'max_iter': 1000, 'max_depth': 7, 'max_bins': 233, 'min_samples_leaf': 96, 'max_leaf_nodes': 48}. Best is trial 1 with value: 0.8746975715968887.
# [I 2023-02-18 15:21:56,836] Trial 4 finished with value: 0.8725218430772121 and parameters: {'l2_regularization': 0.633847627398134, 'early_stopping': 'False', 'learning_rate': 0.06562646591152031, 'max_iter': 1000, 'max_depth': 3, 'max_bins': 166, 'min_samples_leaf': 72, 'max_leaf_nodes': 97}. Best is trial 1 with value: 0.8746975715968887.
# [I 2023-02-18 15:22:35,673] Trial 5 finished with value: 0.8604496706417407 and parameters: {'l2_regularization': 0.23502086057307048, 'early_stopping': 'False', 'learning_rate': 0.0010395033683646155, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 190, 'min_samples_leaf': 67, 'max_leaf_nodes': 45}. Best is trial 1 with value: 0.8746975715968887.
# [I 2023-02-18 15:22:40,434] Trial 6 finished with value: 0.8757654688697449 and parameters: {'l2_regularization': 0.026804402059541738, 'early_stopping': 'False', 'learning_rate': 0.11390860384237776, 'max_iter': 1000, 'max_depth': 9, 'max_bins': 222, 'min_samples_leaf': 78, 'max_leaf_nodes': 24}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:23:16,446] Trial 7 finished with value: 0.8694314682334365 and parameters: {'l2_regularization': 0.0468482501291689, 'early_stopping': 'False', 'learning_rate': 0.004594813070530207, 'max_iter': 1000, 'max_depth': 14, 'max_bins': 128, 'min_samples_leaf': 26, 'max_leaf_nodes': 42}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:24:17,084] Trial 8 finished with value: 0.8663424445908131 and parameters: {'l2_regularization': 0.43697170187644563, 'early_stopping': 'False', 'learning_rate': 0.0021437355024352175, 'max_iter': 1000, 'max_depth': 14, 'max_bins': 112, 'min_samples_leaf': 58, 'max_leaf_nodes': 74}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:24:18,242] Trial 9 finished with value: 0.8687044693996058 and parameters: {'l2_regularization': 0.15882755933166443, 'early_stopping': 'False', 'learning_rate': 0.8057597603073205, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 251, 'min_samples_leaf': 48, 'max_leaf_nodes': 51}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:24:36,879] Trial 10 finished with value: 0.8754682599010668 and parameters: {'l2_regularization': 5.3217296039848625, 'early_stopping': 'False', 'learning_rate': 0.02814954090779189, 'max_iter': 1000, 'max_depth': 7, 'max_bins': 205, 'min_samples_leaf': 92, 'max_leaf_nodes': 21}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:24:55,318] Trial 11 finished with value: 0.8753126933796448 and parameters: {'l2_regularization': 6.110569345482144, 'early_stopping': 'False', 'learning_rate': 0.02420030751623164, 'max_iter': 1000, 'max_depth': 7, 'max_bins': 210, 'min_samples_leaf': 92, 'max_leaf_nodes': 22}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:25:06,175] Trial 12 finished with value: 0.8738721308948658 and parameters: {'l2_regularization': 9.066782152894055, 'early_stopping': 'False', 'learning_rate': 0.04280984953230019, 'max_iter': 1000, 'max_depth': 7, 'max_bins': 158, 'min_samples_leaf': 83, 'max_leaf_nodes': 23}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:25:26,285] Trial 13 finished with value: 0.8735689997802517 and parameters: {'l2_regularization': 0.01312488586955198, 'early_stopping': 'False', 'learning_rate': 0.016197033659833826, 'max_iter': 1000, 'max_depth': 5, 'max_bins': 208, 'min_samples_leaf': 82, 'max_leaf_nodes': 35}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:25:31,844] Trial 14 finished with value: 0.8754758717453214 and parameters: {'l2_regularization': 2.8595759731708466, 'early_stopping': 'False', 'learning_rate': 0.1077427387914007, 'max_iter': 1000, 'max_depth': 12, 'max_bins': 204, 'min_samples_leaf': 83, 'max_leaf_nodes': 63}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:25:37,199] Trial 15 finished with value: 0.8744211345725361 and parameters: {'l2_regularization': 2.419403792333293, 'early_stopping': 'False', 'learning_rate': 0.11772713913077101, 'max_iter': 1000, 'max_depth': 12, 'max_bins': 147, 'min_samples_leaf': 78, 'max_leaf_nodes': 64}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:25:41,006] Trial 16 finished with value: 0.8754629266931777 and parameters: {'l2_regularization': 0.09335733696391568, 'early_stopping': 'False', 'learning_rate': 0.19003097848043526, 'max_iter': 1000, 'max_depth': 12, 'max_bins': 230, 'min_samples_leaf': 53, 'max_leaf_nodes': 71}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:25:48,995] Trial 17 finished with value: 0.8748089601306281 and parameters: {'l2_regularization': 1.59832314373272, 'early_stopping': 'False', 'learning_rate': 0.07356596724781075, 'max_iter': 1000, 'max_depth': 12, 'max_bins': 194, 'min_samples_leaf': 44, 'max_leaf_nodes': 80}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:25:50,987] Trial 18 finished with value: 0.8739876348804149 and parameters: {'l2_regularization': 0.03825131921420541, 'early_stopping': 'False', 'learning_rate': 0.31368758664193586, 'max_iter': 1000, 'max_depth': 15, 'max_bins': 172, 'min_samples_leaf': 74, 'max_leaf_nodes': 58}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:25:55,407] Trial 19 finished with value: 0.8755111571912142 and parameters: {'l2_regularization': 0.15349776248362154, 'early_stopping': 'False', 'learning_rate': 0.11542215083373414, 'max_iter': 1000, 'max_depth': 9, 'max_bins': 220, 'min_samples_leaf': 88, 'max_leaf_nodes': 58}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:25:57,213] Trial 20 finished with value: 0.87421043993239 and parameters: {'l2_regularization': 0.1078689472929528, 'early_stopping': 'False', 'learning_rate': 0.4081547388146842, 'max_iter': 1000, 'max_depth': 9, 'max_bins': 221, 'min_samples_leaf': 88, 'max_leaf_nodes': 35}. Best is trial 6 with value: 0.8757654688697449.
# [I 2023-02-18 15:26:01,369] Trial 21 finished with value: 0.8758755059327582 and parameters: {'l2_regularization': 0.22391437696359143, 'early_stopping': 'False', 'learning_rate': 0.1456692539695885, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 241, 'min_samples_leaf': 98, 'max_leaf_nodes': 60}. Best is trial 21 with value: 0.8758755059327582.
# [I 2023-02-18 15:26:04,735] Trial 22 finished with value: 0.8755309539821117 and parameters: {'l2_regularization': 0.22286608540413094, 'early_stopping': 'False', 'learning_rate': 0.18572893238130642, 'max_iter': 1000, 'max_depth': 8, 'max_bins': 242, 'min_samples_leaf': 98, 'max_leaf_nodes': 55}. Best is trial 21 with value: 0.8758755059327582.
# [I 2023-02-18 15:26:08,213] Trial 23 finished with value: 0.8758043406919043 and parameters: {'l2_regularization': 0.06016430431513165, 'early_stopping': 'False', 'learning_rate': 0.19542208096217004, 'max_iter': 1000, 'max_depth': 8, 'max_bins': 239, 'min_samples_leaf': 100, 'max_leaf_nodes': 83}. Best is trial 21 with value: 0.8758755059327582.
# [I 2023-02-18 15:26:10,131] Trial 24 finished with value: 0.8746560105343271 and parameters: {'l2_regularization': 0.05075545610917668, 'early_stopping': 'False', 'learning_rate': 0.4353326621063904, 'max_iter': 1000, 'max_depth': 5, 'max_bins': 237, 'min_samples_leaf': 100, 'max_leaf_nodes': 85}. Best is trial 21 with value: 0.8758755059327582.
# [I 2023-02-18 15:26:12,786] Trial 25 finished with value: 0.875136974715447 and parameters: {'l2_regularization': 0.024721159858986746, 'early_stopping': 'False', 'learning_rate': 0.247043034915489, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 255, 'min_samples_leaf': 91, 'max_leaf_nodes': 71}. Best is trial 21 with value: 0.8758755059327582.
# [I 2023-02-18 15:26:16,948] Trial 26 finished with value: 0.8760754760828025 and parameters: {'l2_regularization': 0.07370591971845113, 'early_stopping': 'False', 'learning_rate': 0.1455170690585563, 'max_iter': 1000, 'max_depth': 8, 'max_bins': 242, 'min_samples_leaf': 99, 'max_leaf_nodes': 76}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:26:18,910] Trial 27 finished with value: 0.8751710539685995 and parameters: {'l2_regularization': 0.0821994147722828, 'early_stopping': 'False', 'learning_rate': 0.34421846329420386, 'max_iter': 1000, 'max_depth': 6, 'max_bins': 244, 'min_samples_leaf': 100, 'max_leaf_nodes': 80}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:26:29,797] Trial 28 finished with value: 0.8758620989625971 and parameters: {'l2_regularization': 0.08549417077567896, 'early_stopping': 'False', 'learning_rate': 0.05223142084812238, 'max_iter': 1000, 'max_depth': 8, 'max_bins': 255, 'min_samples_leaf': 37, 'max_leaf_nodes': 77}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:26:44,862] Trial 29 finished with value: 0.8754222334357736 and parameters: {'l2_regularization': 0.010775011877934629, 'early_stopping': 'False', 'learning_rate': 0.0593373229149942, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 255, 'min_samples_leaf': 37, 'max_leaf_nodes': 90}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:26:46,287] Trial 30 finished with value: 0.8713046413467007 and parameters: {'l2_regularization': 0.14133842485182865, 'early_stopping': 'False', 'learning_rate': 0.8804753452067324, 'max_iter': 1000, 'max_depth': 2, 'max_bins': 228, 'min_samples_leaf': 36, 'max_leaf_nodes': 68}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:26:50,450] Trial 31 finished with value: 0.8754775289376141 and parameters: {'l2_regularization': 0.062421822468076, 'early_stopping': 'False', 'learning_rate': 0.15352314230853692, 'max_iter': 1000, 'max_depth': 8, 'max_bins': 241, 'min_samples_leaf': 64, 'max_leaf_nodes': 77}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:26:53,718] Trial 32 finished with value: 0.8746958131907748 and parameters: {'l2_regularization': 0.06688096582839073, 'early_stopping': 'False', 'learning_rate': 0.21851920940813271, 'max_iter': 1000, 'max_depth': 8, 'max_bins': 237, 'min_samples_leaf': 20, 'max_leaf_nodes': 89}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:26:55,259] Trial 33 finished with value: 0.8734309994803595 and parameters: {'l2_regularization': 0.10771954260251887, 'early_stopping': 'False', 'learning_rate': 0.5271307156460722, 'max_iter': 1000, 'max_depth': 6, 'max_bins': 216, 'min_samples_leaf': 95, 'max_leaf_nodes': 80}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:27:02,009] Trial 34 finished with value: 0.8754420786127108 and parameters: {'l2_regularization': 0.019860683705850042, 'early_stopping': 'False', 'learning_rate': 0.07613704037172501, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 248, 'min_samples_leaf': 88, 'max_leaf_nodes': 85}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:27:04,141] Trial 35 finished with value: 0.875099076305711 and parameters: {'l2_regularization': 0.03354787484832436, 'early_stopping': 'False', 'learning_rate': 0.27964673746376545, 'max_iter': 1000, 'max_depth': 6, 'max_bins': 232, 'min_samples_leaf': 95, 'max_leaf_nodes': 96}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:27:05,739] Trial 36 finished with value: 0.8716829799006207 and parameters: {'l2_regularization': 0.2913631030821817, 'early_stopping': 'False', 'learning_rate': 0.586341596568447, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 245, 'min_samples_leaf': 44, 'max_leaf_nodes': 66}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:27:10,155] Trial 37 finished with value: 0.8745735580710436 and parameters: {'l2_regularization': 0.07119064303310187, 'early_stopping': 'False', 'learning_rate': 0.15127652258430585, 'max_iter': 1000, 'max_depth': 9, 'max_bins': 196, 'min_samples_leaf': 70, 'max_leaf_nodes': 84}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:27:22,816] Trial 38 finished with value: 0.8748762733180543 and parameters: {'l2_regularization': 0.44997264564249134, 'early_stopping': 'False', 'learning_rate': 0.045823003840059426, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 226, 'min_samples_leaf': 56, 'max_leaf_nodes': 93}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:27:25,210] Trial 39 finished with value: 0.8744179759659056 and parameters: {'l2_regularization': 0.04114747261065476, 'early_stopping': 'False', 'learning_rate': 0.27579338195427244, 'max_iter': 1000, 'max_depth': 8, 'max_bins': 214, 'min_samples_leaf': 64, 'max_leaf_nodes': 71}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:27:30,231] Trial 40 finished with value: 0.8756071427336382 and parameters: {'l2_regularization': 0.2028767675555867, 'early_stopping': 'False', 'learning_rate': 0.09182443894052093, 'max_iter': 1000, 'max_depth': 13, 'max_bins': 235, 'min_samples_leaf': 33, 'max_leaf_nodes': 53}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:27:34,241] Trial 41 finished with value: 0.8760503321556152 and parameters: {'l2_regularization': 0.02704413877456061, 'early_stopping': 'False', 'learning_rate': 0.13230541905792784, 'max_iter': 1000, 'max_depth': 9, 'max_bins': 249, 'min_samples_leaf': 77, 'max_leaf_nodes': 41}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:27:43,124] Trial 42 finished with value: 0.8759936059339605 and parameters: {'l2_regularization': 0.018013400370388094, 'early_stopping': 'False', 'learning_rate': 0.08920495188902818, 'max_iter': 1000, 'max_depth': 9, 'max_bins': 248, 'min_samples_leaf': 96, 'max_leaf_nodes': 100}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:27:50,541] Trial 43 finished with value: 0.8751914476639072 and parameters: {'l2_regularization': 0.017103679825537687, 'early_stopping': 'False', 'learning_rate': 0.06284012484489193, 'max_iter': 1000, 'max_depth': 9, 'max_bins': 255, 'min_samples_leaf': 77, 'max_leaf_nodes': 45}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:27:56,226] Trial 44 finished with value: 0.8759551460195049 and parameters: {'l2_regularization': 0.03045708420508883, 'early_stopping': 'False', 'learning_rate': 0.127418172560096, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 248, 'min_samples_leaf': 86, 'max_leaf_nodes': 98}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:28:05,417] Trial 45 finished with value: 0.8757670545344232 and parameters: {'l2_regularization': 0.02832498011102117, 'early_stopping': 'False', 'learning_rate': 0.08925694845359515, 'max_iter': 1000, 'max_depth': 11, 'max_bins': 247, 'min_samples_leaf': 85, 'max_leaf_nodes': 100}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:28:10,220] Trial 46 finished with value: 0.8739326442036159 and parameters: {'l2_regularization': 0.020842510910737213, 'early_stopping': 'False', 'learning_rate': 0.13567740896869898, 'max_iter': 1000, 'max_depth': 13, 'max_bins': 134, 'min_samples_leaf': 94, 'max_leaf_nodes': 39}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:28:16,351] Trial 47 finished with value: 0.8750854889432371 and parameters: {'l2_regularization': 0.030171650010807315, 'early_stopping': 'False', 'learning_rate': 0.14766840322425273, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 181, 'min_samples_leaf': 90, 'max_leaf_nodes': 99}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:28:22,117] Trial 48 finished with value: 0.8758540529225571 and parameters: {'l2_regularization': 0.01553448256167288, 'early_stopping': 'False', 'learning_rate': 0.09678221525666994, 'max_iter': 1000, 'max_depth': 10, 'max_bins': 229, 'min_samples_leaf': 79, 'max_leaf_nodes': 28}. Best is trial 26 with value: 0.8760754760828025.
# [I 2023-02-18 15:28:40,205] Trial 49 finished with value: 0.8755555329215576 and parameters: {'l2_regularization': 0.04503957751191408, 'early_stopping': 'False', 'learning_rate': 0.04047231681176567, 'max_iter': 1000, 'max_depth': 13, 'max_bins': 248, 'min_samples_leaf': 97, 'max_leaf_nodes': 93}. Best is trial 26 with value: 0.8760754760828025.

# %%
study.best_trial.values
# Out:
# [0.8760754760828025]

# %%
study.best_trial.params
# Out:
# {'l2_regularization': 0.07370591971845113,
#  'early_stopping': 'False',
#  'learning_rate': 0.1455170690585563,
#  'max_iter': 1000,
#  'max_depth': 8,
#  'max_bins': 242,
#  'min_samples_leaf': 99,
#  'max_leaf_nodes': 76}

# %% [markdown]
# # Cross Validation

# %%
hist_cv_scores, roc_auc_scores, hist_imp = list(), list(), list()
preds = list()

## Running 5 times CV
for i in range(5):
    
    skf = StratifiedKFold(n_splits = 5, random_state = 42, shuffle = True)
    
    for train_ix, test_ix in skf.split(X, Y):
        
        ## Splitting the data 
        X_train, X_test = X.iloc[train_ix], X.iloc[test_ix]
        Y_train, Y_test = Y.iloc[train_ix], Y.iloc[test_ix]
                
        ## Building RF model
        hist_md = HistGradientBoostingClassifier(l2_regularization = 0.07370591971845113,
                                                early_stopping = 'False',
                                                learning_rate = 0.1455170690585563,
                                                max_iter = 1000,
                                                max_depth = 8,
                                                max_bins = 242,
                                                min_samples_leaf = 99,
                                                max_leaf_nodes = 76).fit(X_train, Y_train)
#         hist_imp.append(hist_md.feature_importances_)
        
        ## Predicting on X_test and test
        Hist_pred_1 = hist_md.predict_proba(X_test)[:, 1]
        Hist_pred_2 = hist_md.predict_proba(test_lgb)[:, 1]
        
        ## Computing roc-auc score
        roc_auc_scores.append(roc_auc_score(Y_test, Hist_pred_1))
        preds.append(Hist_pred_2)

    hist_cv_scores.append(np.mean(roc_auc_scores))
    
Hist_cv_score = np.mean(hist_cv_scores)    
print('The average oof roc-auc score over 5-folds (run 5 times) is:', Hist_cv_score)
# Out:
# The average oof roc-auc score over 5-folds (run 5 times) is: 0.8760148346614456

# %%
Hist_preds_test = pd.DataFrame(preds).apply(np.mean, axis = 0)

submission['booking_status'] = Hist_preds_test
submission.head()
# Out:
#       id  booking_status
# 0  42100        0.248145
# 1  42101        0.320754
# 2  42102        0.158500
# 3  42103        0.029731
# 4  42104        0.540516

# %%
submission.to_csv('Hist_6_features_optuna_submission.csv', index = False)
