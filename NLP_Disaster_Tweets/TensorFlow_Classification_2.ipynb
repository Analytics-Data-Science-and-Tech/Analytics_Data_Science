# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.multiclass import OneVsRestClassifier
import tensorflow as tf

train = pd.read_csv('train_1.csv')
train = train.fillna(0)

test = pd.read_csv('test_1.csv')
test = test.fillna(0)

test_id = test['id']
test = test.drop(columns = ['id', 'keyword', 'location', 'text', 'clean_tweet'], axis = 1)

## Defining input and target variables 
X = train.drop(columns = ['id', 'keyword', 'location', 'text', 'clean_tweet', 'target'], axis = 1)
Y = train['target']

## Splitting the data 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

## Scaling the data 
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
test = scaler.fit_transform(test)

## Defining model 
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(8, input_dim = 115, activation = 'relu'),
        tf.keras.layers.Dense(8, activation = 'relu'),
        tf.keras.layers.Dense(2, activation = 'softmax')
])

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

## Fitting model 
model.fit(X_train, tf.keras.utils.to_categorical(Y_train, num_classes = 2), epochs = 50, batch_size = 32, validation_data = (X_test, tf.keras.utils.to_categorical(Y_test, num_classes = 2)))

## Predicting on train and test
nn_train_pred = model.predict(X_train)[:, 1]
nn_test_pred = model.predict(test)[:, 1]


def precision_recall_cutoff(Y_test, Y_pred):
    
    ## Computing the precision recall curve
    precision, recall, thresholds = precision_recall_curve(Y_test, Y_pred)
    
    ## Creating the precision-recall data-frame
    precision_recall = pd.DataFrame({'precision': precision[:-1], 'recall': recall[:-1], 'cutoff': thresholds})
    
    ## Finding the optimal cutoff (closest to precision = 1, recall = 1)
    precision_recall['1_minus_precision'] = 1 - precision_recall['precision']
    precision_recall['1_minus_recall'] = 1 - precision_recall['recall']
    precision_recall['Distance_to_perfect_model'] = np.sqrt(precision_recall['1_minus_precision']**2 + precision_recall['1_minus_recall']**2)
    
    ## Sorting based on Distance 
    precision_recall = precision_recall.sort_values(by = 'Distance_to_perfect_model').reset_index(drop = True)
        
    return precision_recall['cutoff'][0]

opt_cutoff = precision_recall_cutoff(Y_train, nn_train_pred)
print('The optimal cutoff is', opt_cutoff)

## Changing likelihoods to labels
nn_test_label = np.where(nn_test_pred < opt_cutoff, 0, 1)

## Creating data-frame for submission
data_out = pd.DataFrame({'id': test_id, 'target': nn_test_label})
data_out.to_csv('network_submission_6.csv', index = False)
# Out:
# Epoch 1/50
# 191/191 [==============================] - 1s 2ms/step - loss: 0.6682 - accuracy: 0.5992 - val_loss: 0.6431 - val_accuracy: 0.6481
# Epoch 2/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.6017 - accuracy: 0.6890 - val_loss: 0.6014 - val_accuracy: 0.6802
# Epoch 3/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5592 - accuracy: 0.7159 - val_loss: 0.5715 - val_accuracy: 0.7058
# Epoch 4/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5438 - accuracy: 0.7220 - val_loss: 0.5620 - val_accuracy: 0.7072
# Epoch 5/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5365 - accuracy: 0.7258 - val_loss: 0.5592 - val_accuracy: 0.7085
# Epoch 6/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5321 - accuracy: 0.7281 - val_loss: 0.5636 - val_accuracy: 0.7065
# Epoch 7/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5294 - accuracy: 0.7276 - val_loss: 0.5555 - val_accuracy: 0.7111
# Epoch 8/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5259 - accuracy: 0.7287 - val_loss: 0.5607 - val_accuracy: 0.7131
# Epoch 9/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5231 - accuracy: 0.7294 - val_loss: 0.5572 - val_accuracy: 0.7111
# Epoch 10/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5217 - accuracy: 0.7342 - val_loss: 0.5616 - val_accuracy: 0.7085
# Epoch 11/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5191 - accuracy: 0.7338 - val_loss: 0.5603 - val_accuracy: 0.7098
# Epoch 12/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5177 - accuracy: 0.7351 - val_loss: 0.5576 - val_accuracy: 0.7131
# Epoch 13/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5143 - accuracy: 0.7386 - val_loss: 0.5574 - val_accuracy: 0.7098
# Epoch 14/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5133 - accuracy: 0.7337 - val_loss: 0.5567 - val_accuracy: 0.7104
# Epoch 15/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5119 - accuracy: 0.7379 - val_loss: 0.5696 - val_accuracy: 0.6999
# Epoch 16/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5107 - accuracy: 0.7373 - val_loss: 0.5728 - val_accuracy: 0.7019
# Epoch 17/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5091 - accuracy: 0.7371 - val_loss: 0.5620 - val_accuracy: 0.7065
# Epoch 18/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5066 - accuracy: 0.7397 - val_loss: 0.5597 - val_accuracy: 0.7124
# Epoch 19/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5056 - accuracy: 0.7424 - val_loss: 0.5619 - val_accuracy: 0.7098
# Epoch 20/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5036 - accuracy: 0.7427 - val_loss: 0.5649 - val_accuracy: 0.7052
# Epoch 21/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5033 - accuracy: 0.7414 - val_loss: 0.5644 - val_accuracy: 0.7104
# Epoch 22/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5017 - accuracy: 0.7448 - val_loss: 0.5654 - val_accuracy: 0.7111
# Epoch 23/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5012 - accuracy: 0.7427 - val_loss: 0.5685 - val_accuracy: 0.7012
# Epoch 24/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4999 - accuracy: 0.7429 - val_loss: 0.5742 - val_accuracy: 0.7026
# Epoch 25/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4993 - accuracy: 0.7450 - val_loss: 0.5662 - val_accuracy: 0.7065
# Epoch 26/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4978 - accuracy: 0.7506 - val_loss: 0.5724 - val_accuracy: 0.7104
# Epoch 27/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4963 - accuracy: 0.7512 - val_loss: 0.5678 - val_accuracy: 0.7111
# Epoch 28/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4958 - accuracy: 0.7470 - val_loss: 0.5745 - val_accuracy: 0.7045
# Epoch 29/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4946 - accuracy: 0.7504 - val_loss: 0.5695 - val_accuracy: 0.7052
# Epoch 30/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4941 - accuracy: 0.7498 - val_loss: 0.5747 - val_accuracy: 0.7111
# Epoch 31/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4930 - accuracy: 0.7488 - val_loss: 0.5703 - val_accuracy: 0.7078
# Epoch 32/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4926 - accuracy: 0.7475 - val_loss: 0.5833 - val_accuracy: 0.7045
# Epoch 33/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4906 - accuracy: 0.7514 - val_loss: 0.5741 - val_accuracy: 0.7150
# Epoch 34/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4914 - accuracy: 0.7530 - val_loss: 0.5768 - val_accuracy: 0.7131
# Epoch 35/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4891 - accuracy: 0.7530 - val_loss: 0.5778 - val_accuracy: 0.7058
# Epoch 36/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4912 - accuracy: 0.7475 - val_loss: 0.5762 - val_accuracy: 0.7137
# Epoch 37/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4878 - accuracy: 0.7507 - val_loss: 0.5794 - val_accuracy: 0.7045
# Epoch 38/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4879 - accuracy: 0.7544 - val_loss: 0.5829 - val_accuracy: 0.6993
# Epoch 39/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4885 - accuracy: 0.7529 - val_loss: 0.5779 - val_accuracy: 0.7124
# Epoch 40/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4867 - accuracy: 0.7522 - val_loss: 0.5839 - val_accuracy: 0.7072
# Epoch 41/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4849 - accuracy: 0.7570 - val_loss: 0.5886 - val_accuracy: 0.6934
# Epoch 42/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4837 - accuracy: 0.7532 - val_loss: 0.5817 - val_accuracy: 0.7118
# Epoch 43/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4844 - accuracy: 0.7524 - val_loss: 0.5845 - val_accuracy: 0.7118
# Epoch 44/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4829 - accuracy: 0.7557 - val_loss: 0.5853 - val_accuracy: 0.6993
# Epoch 45/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4842 - accuracy: 0.7548 - val_loss: 0.5887 - val_accuracy: 0.7078
# Epoch 46/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4839 - accuracy: 0.7558 - val_loss: 0.5863 - val_accuracy: 0.7091
# Epoch 47/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4833 - accuracy: 0.7583 - val_loss: 0.5880 - val_accuracy: 0.7072
# Epoch 48/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4813 - accuracy: 0.7565 - val_loss: 0.5908 - val_accuracy: 0.7019
# Epoch 49/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4797 - accuracy: 0.7589 - val_loss: 0.5883 - val_accuracy: 0.7091
# Epoch 50/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4802 - accuracy: 0.7535 - val_loss: 0.5866 - val_accuracy: 0.7137
# The optimal cutoff is 0.37966877
