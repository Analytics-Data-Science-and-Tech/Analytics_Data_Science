# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.multiclass import OneVsRestClassifier
import tensorflow as tf

train = pd.read_csv('train_2.csv')
train = train.fillna(0)

test = pd.read_csv('test_2.csv')
test = test.fillna(0)

test_id = test['id']
test = test.drop(columns = ['id', 'keyword', 'location', 'text', 'clean_tweet'], axis = 1)

## Defining input and target variables 
X = train.drop(columns = ['id', 'keyword', 'location', 'text', 'clean_tweet', 'target'], axis = 1)
Y = train['target']

## Splitting the data 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

## Scaling the data 
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
test = scaler.fit_transform(test)

## Defining model 
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(10, input_dim = 165, activation = 'relu'),
        tf.keras.layers.Dense(10, activation = 'relu'),
        tf.keras.layers.Dense(2, activation = 'softmax')
])

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

## Fitting model 
model.fit(X_train, tf.keras.utils.to_categorical(Y_train, num_classes = 2), epochs = 50, batch_size = 32, validation_data = (X_test, tf.keras.utils.to_categorical(Y_test, num_classes = 2)))

## Predicting on train and test
nn_train_pred = model.predict(X_train)[:, 1]
nn_test_pred = model.predict(test)[:, 1]


def precision_recall_cutoff(Y_test, Y_pred):
    
    ## Computing the precision recall curve
    precision, recall, thresholds = precision_recall_curve(Y_test, Y_pred)
    
    ## Creating the precision-recall data-frame
    precision_recall = pd.DataFrame({'precision': precision[:-1], 'recall': recall[:-1], 'cutoff': thresholds})
    
    ## Finding the optimal cutoff (closest to precision = 1, recall = 1)
    precision_recall['1_minus_precision'] = 1 - precision_recall['precision']
    precision_recall['1_minus_recall'] = 1 - precision_recall['recall']
    precision_recall['Distance_to_perfect_model'] = np.sqrt(precision_recall['1_minus_precision']**2 + precision_recall['1_minus_recall']**2)
    
    ## Sorting based on Distance 
    precision_recall = precision_recall.sort_values(by = 'Distance_to_perfect_model').reset_index(drop = True)
        
    return precision_recall['cutoff'][0]

opt_cutoff = precision_recall_cutoff(Y_train, nn_train_pred)
print('The optimal cutoff is', opt_cutoff)

## Changing likelihoods to labels
nn_test_label = np.where(nn_test_pred < opt_cutoff, 0, 1)

## Creating data-frame for submission
data_out = pd.DataFrame({'id': test_id, 'target': nn_test_label})
# data_out.to_csv('network_submission_7.csv', index = False)
# Out:
# Epoch 1/50
# 191/191 [==============================] - 1s 2ms/step - loss: 0.6784 - accuracy: 0.5849 - val_loss: 0.6433 - val_accuracy: 0.6592
# Epoch 2/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5906 - accuracy: 0.7082 - val_loss: 0.5390 - val_accuracy: 0.7262
# Epoch 3/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5381 - accuracy: 0.7328 - val_loss: 0.5209 - val_accuracy: 0.7308
# Epoch 4/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5232 - accuracy: 0.7392 - val_loss: 0.5164 - val_accuracy: 0.7315
# Epoch 5/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5162 - accuracy: 0.7402 - val_loss: 0.5129 - val_accuracy: 0.7347
# Epoch 6/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5136 - accuracy: 0.7366 - val_loss: 0.5125 - val_accuracy: 0.7328
# Epoch 7/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5090 - accuracy: 0.7465 - val_loss: 0.5144 - val_accuracy: 0.7321
# Epoch 8/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5070 - accuracy: 0.7479 - val_loss: 0.5106 - val_accuracy: 0.7393
# Epoch 9/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5042 - accuracy: 0.7460 - val_loss: 0.5172 - val_accuracy: 0.7315
# Epoch 10/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5021 - accuracy: 0.7488 - val_loss: 0.5104 - val_accuracy: 0.7354
# Epoch 11/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4996 - accuracy: 0.7522 - val_loss: 0.5098 - val_accuracy: 0.7328
# Epoch 12/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4967 - accuracy: 0.7540 - val_loss: 0.5093 - val_accuracy: 0.7406
# Epoch 13/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4937 - accuracy: 0.7542 - val_loss: 0.5133 - val_accuracy: 0.7347
# Epoch 14/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4914 - accuracy: 0.7585 - val_loss: 0.5130 - val_accuracy: 0.7433
# Epoch 15/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4886 - accuracy: 0.7599 - val_loss: 0.5179 - val_accuracy: 0.7334
# Epoch 16/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4862 - accuracy: 0.7594 - val_loss: 0.5142 - val_accuracy: 0.7400
# Epoch 17/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4850 - accuracy: 0.7611 - val_loss: 0.5147 - val_accuracy: 0.7400
# Epoch 18/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4829 - accuracy: 0.7585 - val_loss: 0.5197 - val_accuracy: 0.7328
# Epoch 19/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4808 - accuracy: 0.7621 - val_loss: 0.5158 - val_accuracy: 0.7347
# Epoch 20/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4780 - accuracy: 0.7647 - val_loss: 0.5139 - val_accuracy: 0.7374
# Epoch 21/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4762 - accuracy: 0.7672 - val_loss: 0.5196 - val_accuracy: 0.7328
# Epoch 22/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4734 - accuracy: 0.7657 - val_loss: 0.5196 - val_accuracy: 0.7374
# Epoch 23/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4710 - accuracy: 0.7657 - val_loss: 0.5236 - val_accuracy: 0.7452
# Epoch 24/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4711 - accuracy: 0.7673 - val_loss: 0.5246 - val_accuracy: 0.7328
# Epoch 25/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4684 - accuracy: 0.7654 - val_loss: 0.5251 - val_accuracy: 0.7406
# Epoch 26/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4668 - accuracy: 0.7737 - val_loss: 0.5258 - val_accuracy: 0.7341
# Epoch 27/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4641 - accuracy: 0.7678 - val_loss: 0.5294 - val_accuracy: 0.7380
# Epoch 28/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4633 - accuracy: 0.7709 - val_loss: 0.5288 - val_accuracy: 0.7406
# Epoch 29/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4608 - accuracy: 0.7696 - val_loss: 0.5352 - val_accuracy: 0.7301
# Epoch 30/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4592 - accuracy: 0.7732 - val_loss: 0.5327 - val_accuracy: 0.7374
# Epoch 31/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4585 - accuracy: 0.7708 - val_loss: 0.5318 - val_accuracy: 0.7367
# Epoch 32/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4563 - accuracy: 0.7747 - val_loss: 0.5318 - val_accuracy: 0.7360
# Epoch 33/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4556 - accuracy: 0.7744 - val_loss: 0.5347 - val_accuracy: 0.7367
# Epoch 34/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4542 - accuracy: 0.7736 - val_loss: 0.5360 - val_accuracy: 0.7413
# Epoch 35/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4533 - accuracy: 0.7757 - val_loss: 0.5415 - val_accuracy: 0.7360
# Epoch 36/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4527 - accuracy: 0.7775 - val_loss: 0.5399 - val_accuracy: 0.7341
# Epoch 37/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4496 - accuracy: 0.7772 - val_loss: 0.5349 - val_accuracy: 0.7387
# Epoch 38/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.4493 - accuracy: 0.7790 - val_loss: 0.5566 - val_accuracy: 0.7203
# Epoch 39/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4489 - accuracy: 0.7764 - val_loss: 0.5466 - val_accuracy: 0.7334
# Epoch 40/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4464 - accuracy: 0.7836 - val_loss: 0.5403 - val_accuracy: 0.7380
# Epoch 41/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4461 - accuracy: 0.7811 - val_loss: 0.5446 - val_accuracy: 0.7321
# Epoch 42/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4450 - accuracy: 0.7818 - val_loss: 0.5472 - val_accuracy: 0.7315
# Epoch 43/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4436 - accuracy: 0.7806 - val_loss: 0.5540 - val_accuracy: 0.7321
# Epoch 44/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4418 - accuracy: 0.7828 - val_loss: 0.5430 - val_accuracy: 0.7354
# Epoch 45/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4401 - accuracy: 0.7847 - val_loss: 0.5539 - val_accuracy: 0.7295
# Epoch 46/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4390 - accuracy: 0.7834 - val_loss: 0.5543 - val_accuracy: 0.7301
# Epoch 47/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4378 - accuracy: 0.7882 - val_loss: 0.5475 - val_accuracy: 0.7269
# Epoch 48/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.4378 - accuracy: 0.7824 - val_loss: 0.5620 - val_accuracy: 0.7177
# Epoch 49/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4353 - accuracy: 0.7874 - val_loss: 0.5577 - val_accuracy: 0.7255
# Epoch 50/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.4346 - accuracy: 0.7880 - val_loss: 0.5524 - val_accuracy: 0.7269
# The optimal cutoff is 0.3927622
