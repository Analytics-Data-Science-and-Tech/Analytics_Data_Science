# %%
from IPython.display import clear_output
# !pip install sportsdataverse
clear_output()

# %%
import pandas as pd
import sportsdataverse

# %%
#################
## NFL Section ##
#################

def loadNflPbp():
    print('sportsdataverse.nfl.load_nfl_pbp(seasons=range(2019,2021))')
    print('Load NFL play by play data going back to 1999')
    nflPbp = sportsdataverse.nfl.load_nfl_pbp(seasons=range(2019,2021))
    # print(nflPbp)
    return nflPbp

def loadNflPlayerStats():
    print('sportsdataverse.nfl.load_nfl_player_stats()')
    print('Load NFL player stats data')
    nflPlayerStats = sportsdataverse.nfl.load_nfl_player_stats()
    # print(nflPlayerStats)
    return nflPlayerStats

def loadNflRosters():
    print('sportsdataverse.nfl.load_nfl_rosters()')
    print('Load NFL roster data for all seasons')
    nflRosters = sportsdataverse.nfl.load_nfl_rosters()
    # print(nflRosters)
    return nflRosters

def loadNflSchedules():
    print('sportsdataverse.nfl.load_nfl_schedule(seasons=range(2019,2021))')
    print('Load NFL schedule data')
    nflSchedules = sportsdataverse.nfl.load_nfl_schedule(seasons=range(2019,2021))
    # print(nflSchedules)
    return nflSchedules

def loadNflTeams():
    print('sportsdataverse.nfl.load_nfl_teams()')
    print('Load NFL team ID information and logos')
    nflTeams = sportsdataverse.nfl.load_nfl_teams()
    # print(nflTeams)
    return nflTeams

def loadEspnNflCalendar():
    print('portsdataverse.nfl.espn_nfl_calendar(season=2020)')
    print('espn_nfl_calendar - look up the NFL calendar for a given season from ESPN')
    espnNflCalendar = sportsdataverse.nfl.espn_nfl_calendar(season=2020)
    # print(espnNflCalendar)
    return espnNflCalendar

def loadEspnNflSchedule():
    print('sportsdataverse.nfl.espn_nfl_schedule(dates=2020, week=1, season_type=2)')
    print('espn_nfl_schedule - look up the NFL schedule for a given date from ESPN')
    espnNflSchedule = sportsdataverse.nfl.espn_nfl_schedule(dates=2020, week=1, season_type=2)
    # print(espnNflSchedule)
    return espnNflSchedule

# %%
# Loading the NFL data

# PBP = loadNflPbp()
# playerStats = loadNflPlayerStats()
# rosters = loadNflRosters()
schedules = loadNflSchedules()
teams = loadNflTeams()
# calendar = loadEspnNflCalendar()
# schedule_espn = loadEspnNflSchedule()
# Out:
# sportsdataverse.nfl.load_nfl_schedule(seasons=range(2019,2021))
# Load NFL schedule data
# 100%|██████████| 2/2 [00:00<00:00, 16.51it/s]
# sportsdataverse.nfl.load_nfl_teams()
# Load NFL team ID information and logos

# %%
schedules.head()
# Out:
#    Unnamed: 0          game_id  season game_type  week     gameday   weekday  \
# 0           0   2019_01_GB_CHI    2019       REG     1  2019-09-05  Thursday
# 1           1   2019_01_LA_CAR    2019       REG     1  2019-09-08    Sunday
# 2           2  2019_01_TEN_CLE    2019       REG     1  2019-09-08    Sunday
# 3           3   2019_01_KC_JAX    2019       REG     1  2019-09-08    Sunday
# 4           4  2019_01_BAL_MIA    2019       REG     1  2019-09-08    Sunday
#
#   gametime away_team home_team  away_score  home_score  home_result  \
# 0    20:20        GB       CHI          10           3           -7
# 1    13:00        LA       CAR          30          27           -3
# 2    13:00       TEN       CLE          43          13          -30
# 3    13:00        KC       JAX          40          26          -14
# 4    13:00       BAL       MIA          59          10          -49
#
#                    stadium location      roof surface  old_game_id
# 0            Soldier Field     Home  outdoors   grass   2019090500
# 1  Bank of America Stadium     Home  outdoors   grass   2019090800
# 2      FirstEnergy Stadium     Home  outdoors   grass   2019090801
# 3        TIAA Bank Stadium     Home  outdoors   grass   2019090802
# 4        Hard Rock Stadium     Home  outdoors   grass   2019090803

# %%
teams.head()
# Out:
#   team_abbr          team_name  team_id  team_nick team_conf team_division  \
# 0       ARI  Arizona Cardinals     3800  Cardinals       NFC      NFC West
# 1       ATL    Atlanta Falcons      200    Falcons       NFC     NFC South
# 2       BAL   Baltimore Ravens      325     Ravens       AFC     AFC North
# 3       BUF      Buffalo Bills      610      Bills       AFC      AFC East
# 4       CAR  Carolina Panthers      750   Panthers       NFC     NFC South
#
#   team_color team_color2 team_color3 team_color4  \
# 0    #97233F     #000000     #ffb612     #a5acaf
# 1    #A71930     #000000     #a5acaf     #a30d2d
# 2    #241773     #9E7C0C     #9e7c0c     #c60c30
# 3    #00338D     #C60C30     #0c2e82     #d50a0a
# 4    #0085CA     #000000     #bfc0bf     #0085ca
#
#                                  team_logo_wikipedia  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1  https://upload.wikimedia.org/wikipedia/en/thum...
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                       team_logo_espn  \
# 0  https://a.espncdn.com/i/teamlogos/nfl/500/ari.png
# 1  https://a.espncdn.com/i/teamlogos/nfl/500/atl.png
# 2  https://a.espncdn.com/i/teamlogos/nfl/500/bal.png
# 3  https://a.espncdn.com/i/teamlogos/nfl/500/buf.png
# 4  https://a.espncdn.com/i/teamlogos/nfl/500-dark...
#
#                                        team_wordmark  \
# 0  https://github.com/nflverse/nflfastR-data/raw/...
# 1  https://github.com/nflverse/nflfastR-data/raw/...
# 2  https://github.com/nflverse/nflfastR-data/raw/...
# 3  https://github.com/nflverse/nflfastR-data/raw/...
# 4  https://github.com/nflverse/nflfastR-data/raw/...
#
#                                 team_conference_logo  \
# 0  https://github.com/nflverse/nflfastR-data/raw/...
# 1  https://github.com/nflverse/nflfastR-data/raw/...
# 2  https://github.com/nflverse/nflfastR-data/raw/...
# 3  https://github.com/nflverse/nflfastR-data/raw/...
# 4  https://github.com/nflverse/nflfastR-data/raw/...
#
#                                     team_league_logo
# 0  https://raw.githubusercontent.com/nflverse/nfl...
# 1  https://raw.githubusercontent.com/nflverse/nfl...
# 2  https://raw.githubusercontent.com/nflverse/nfl...
# 3  https://raw.githubusercontent.com/nflverse/nfl...
# 4  https://raw.githubusercontent.com/nflverse/nfl...
