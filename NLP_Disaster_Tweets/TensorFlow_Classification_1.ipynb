# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.multiclass import OneVsRestClassifier
import tensorflow as tf

train = pd.read_csv('train_1.csv')
train = train.fillna(0)

test = pd.read_csv('test_1.csv')
test = test.fillna(0)

test_id = test['id']
test = test.drop(columns = ['id', 'keyword', 'location', 'text', 'clean_tweet'], axis = 1)

## Defining input and target variables 
X = train.drop(columns = ['id', 'keyword', 'location', 'text', 'clean_tweet', 'target'], axis = 1)
Y = train['target']

## Splitting the data 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

## Scaling the data 
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
test = scaler.fit_transform(test)

## Defining model 
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(10, input_dim = 115, activation = 'relu'),
#         tf.keras.layers.Dense(10, activation = 'relu'),
        tf.keras.layers.Dense(2, activation = 'softmax')
])

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

## Fitting model 
model.fit(X_train, tf.keras.utils.to_categorical(Y_train, num_classes = 2), epochs = 50, batch_size = 32, validation_data = (X_test, tf.keras.utils.to_categorical(Y_test, num_classes = 2)))

## Predicting on train and test
nn_train_pred = model.predict(X_train)[:, 1]
nn_test_pred = model.predict(test)[:, 1]


def precision_recall_cutoff(Y_test, Y_pred):
    
    ## Computing the precision recall curve
    precision, recall, thresholds = precision_recall_curve(Y_test, Y_pred)
    
    ## Creating the precision-recall data-frame
    precision_recall = pd.DataFrame({'precision': precision[:-1], 'recall': recall[:-1], 'cutoff': thresholds})
    
    ## Finding the optimal cutoff (closest to precision = 1, recall = 1)
    precision_recall['1_minus_precision'] = 1 - precision_recall['precision']
    precision_recall['1_minus_recall'] = 1 - precision_recall['recall']
    precision_recall['Distance_to_perfect_model'] = np.sqrt(precision_recall['1_minus_precision']**2 + precision_recall['1_minus_recall']**2)
    
    ## Sorting based on Distance 
    precision_recall = precision_recall.sort_values(by = 'Distance_to_perfect_model').reset_index(drop = True)
        
    return precision_recall['cutoff'][0]

opt_cutoff = precision_recall_cutoff(Y_train, nn_train_pred)
print('The optimal cutoff is', opt_cutoff)

## Changing likelihoods to labels
nn_test_label = np.where(nn_test_pred < opt_cutoff, 0, 1)

## Creating data-frame for submission
data_out = pd.DataFrame({'id': test_id, 'target': nn_test_label})
data_out.to_csv('network_submission_4.csv', index = False)
# Out:
# Epoch 1/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.6810 - accuracy: 0.5813 - val_loss: 0.6469 - val_accuracy: 0.6494
# Epoch 2/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.6146 - accuracy: 0.6939 - val_loss: 0.5994 - val_accuracy: 0.6809
# Epoch 3/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5675 - accuracy: 0.7158 - val_loss: 0.5767 - val_accuracy: 0.6875
# Epoch 4/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.7227 - val_loss: 0.5687 - val_accuracy: 0.6973
# Epoch 5/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5361 - accuracy: 0.7259 - val_loss: 0.5669 - val_accuracy: 0.7026
# Epoch 6/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5325 - accuracy: 0.7332 - val_loss: 0.5661 - val_accuracy: 0.7012
# Epoch 7/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5300 - accuracy: 0.7274 - val_loss: 0.5655 - val_accuracy: 0.6986
# Epoch 8/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5276 - accuracy: 0.7304 - val_loss: 0.5701 - val_accuracy: 0.7058
# Epoch 9/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5266 - accuracy: 0.7291 - val_loss: 0.5649 - val_accuracy: 0.6986
# Epoch 10/50
# 191/191 [==============================] - 0s 3ms/step - loss: 0.5250 - accuracy: 0.7302 - val_loss: 0.5645 - val_accuracy: 0.7032
# Epoch 11/50
# 191/191 [==============================] - 0s 3ms/step - loss: 0.5235 - accuracy: 0.7315 - val_loss: 0.5639 - val_accuracy: 0.7045
# Epoch 12/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5223 - accuracy: 0.7319 - val_loss: 0.5770 - val_accuracy: 0.7026
# Epoch 13/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5230 - accuracy: 0.7314 - val_loss: 0.5658 - val_accuracy: 0.7032
# Epoch 14/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5211 - accuracy: 0.7343 - val_loss: 0.5639 - val_accuracy: 0.7052
# Epoch 15/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5199 - accuracy: 0.7365 - val_loss: 0.5639 - val_accuracy: 0.7026
# Epoch 16/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5197 - accuracy: 0.7335 - val_loss: 0.5643 - val_accuracy: 0.7039
# Epoch 17/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5188 - accuracy: 0.7371 - val_loss: 0.5646 - val_accuracy: 0.7072
# Epoch 18/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5175 - accuracy: 0.7371 - val_loss: 0.5665 - val_accuracy: 0.7072
# Epoch 19/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5177 - accuracy: 0.7365 - val_loss: 0.5651 - val_accuracy: 0.6993
# Epoch 20/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5164 - accuracy: 0.7363 - val_loss: 0.5649 - val_accuracy: 0.7091
# Epoch 21/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5160 - accuracy: 0.7353 - val_loss: 0.5648 - val_accuracy: 0.7019
# Epoch 22/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5149 - accuracy: 0.7363 - val_loss: 0.5643 - val_accuracy: 0.6986
# Epoch 23/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5140 - accuracy: 0.7384 - val_loss: 0.5665 - val_accuracy: 0.7085
# Epoch 24/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5126 - accuracy: 0.7365 - val_loss: 0.5719 - val_accuracy: 0.7078
# Epoch 25/50
# 191/191 [==============================] - 0s 3ms/step - loss: 0.5135 - accuracy: 0.7379 - val_loss: 0.5632 - val_accuracy: 0.7072
# Epoch 26/50
# 191/191 [==============================] - 0s 3ms/step - loss: 0.5121 - accuracy: 0.7407 - val_loss: 0.5671 - val_accuracy: 0.7085
# Epoch 27/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5114 - accuracy: 0.7414 - val_loss: 0.5642 - val_accuracy: 0.7098
# Epoch 28/50
# 191/191 [==============================] - 0s 3ms/step - loss: 0.5110 - accuracy: 0.7360 - val_loss: 0.5641 - val_accuracy: 0.7085
# Epoch 29/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5102 - accuracy: 0.7425 - val_loss: 0.5647 - val_accuracy: 0.7058
# Epoch 30/50
# 191/191 [==============================] - 0s 3ms/step - loss: 0.5080 - accuracy: 0.7406 - val_loss: 0.5654 - val_accuracy: 0.7019
# Epoch 31/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.5080 - accuracy: 0.7432 - val_loss: 0.5649 - val_accuracy: 0.7124
# Epoch 32/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5073 - accuracy: 0.7407 - val_loss: 0.5670 - val_accuracy: 0.7065
# Epoch 33/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5076 - accuracy: 0.7392 - val_loss: 0.5656 - val_accuracy: 0.7065
# Epoch 34/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5051 - accuracy: 0.7425 - val_loss: 0.5666 - val_accuracy: 0.7072
# Epoch 35/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5048 - accuracy: 0.7447 - val_loss: 0.5667 - val_accuracy: 0.7045
# Epoch 36/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5038 - accuracy: 0.7429 - val_loss: 0.5655 - val_accuracy: 0.7039
# Epoch 37/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.7455 - val_loss: 0.5656 - val_accuracy: 0.7085
# Epoch 38/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.5034 - accuracy: 0.7425 - val_loss: 0.5644 - val_accuracy: 0.7098
# Epoch 39/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5023 - accuracy: 0.7475 - val_loss: 0.5656 - val_accuracy: 0.7111
# Epoch 40/50
# 191/191 [==============================] - 0s 3ms/step - loss: 0.5022 - accuracy: 0.7453 - val_loss: 0.5653 - val_accuracy: 0.7072
# Epoch 41/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5010 - accuracy: 0.7478 - val_loss: 0.5642 - val_accuracy: 0.7085
# Epoch 42/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5001 - accuracy: 0.7463 - val_loss: 0.5664 - val_accuracy: 0.7032
# Epoch 43/50
# 191/191 [==============================] - 1s 4ms/step - loss: 0.4990 - accuracy: 0.7455 - val_loss: 0.5650 - val_accuracy: 0.7098
# Epoch 44/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.4981 - accuracy: 0.7430 - val_loss: 0.5684 - val_accuracy: 0.7111
# Epoch 45/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.4986 - accuracy: 0.7484 - val_loss: 0.5642 - val_accuracy: 0.7085
# Epoch 46/50
# 191/191 [==============================] - 0s 3ms/step - loss: 0.4983 - accuracy: 0.7478 - val_loss: 0.5657 - val_accuracy: 0.7058
# Epoch 47/50
# 191/191 [==============================] - 1s 3ms/step - loss: 0.4968 - accuracy: 0.7496 - val_loss: 0.5664 - val_accuracy: 0.7078
# Epoch 48/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.4970 - accuracy: 0.7458 - val_loss: 0.5651 - val_accuracy: 0.7039
# Epoch 49/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.4952 - accuracy: 0.7493 - val_loss: 0.5663 - val_accuracy: 0.7032
# Epoch 50/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.4960 - accuracy: 0.7481 - val_loss: 0.5682 - val_accuracy: 0.7065
# The optimal cutoff is 0.33768347
