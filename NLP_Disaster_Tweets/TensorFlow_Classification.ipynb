# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.multiclass import OneVsRestClassifier
import tensorflow as tf

train = pd.read_csv('train.csv')
train = train.fillna(0)

test = pd.read_csv('test.csv')
test = test.fillna(0)

test_id = test['id']
test = test.drop(columns = ['id', 'keyword', 'location', 'text', 'clean_tweet'], axis = 1)

## Defining input and target variables 
X = train.drop(columns = ['id', 'keyword', 'location', 'text', 'clean_tweet', 'target'], axis = 1)
Y = train['target']

## Splitting the data 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

## Scaling the data 
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
test = scaler.fit_transform(test)

## Defining model 
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(10, input_dim = 15, activation = 'relu'),
        tf.keras.layers.Dense(10, activation = 'relu'),
        tf.keras.layers.Dense(2, activation = 'softmax')
])

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

## Fitting model 
model.fit(X_train, tf.keras.utils.to_categorical(Y_train, num_classes = 2), epochs = 20, batch_size = 32, validation_data = (X_test, tf.keras.utils.to_categorical(Y_test, num_classes = 2)))

## Predicting on train and test
nn_train_pred = model.predict(X_train)[:, 1]
nn_test_pred = model.predict(test)[:, 1]


def precision_recall_cutoff(Y_test, Y_pred):
    
    ## Computing the precision recall curve
    precision, recall, thresholds = precision_recall_curve(Y_test, Y_pred)
    
    ## Creating the precision-recall data-frame
    precision_recall = pd.DataFrame({'precision': precision[:-1], 'recall': recall[:-1], 'cutoff': thresholds})
    
    ## Finding the optimal cutoff (closest to precision = 1, recall = 1)
    precision_recall['1_minus_precision'] = 1 - precision_recall['precision']
    precision_recall['1_minus_recall'] = 1 - precision_recall['recall']
    precision_recall['Distance_to_perfect_model'] = np.sqrt(precision_recall['1_minus_precision']**2 + precision_recall['1_minus_recall']**2)
    
    ## Sorting based on Distance 
    precision_recall = precision_recall.sort_values(by = 'Distance_to_perfect_model').reset_index(drop = True)
        
    return precision_recall['cutoff'][0]

opt_cutoff = precision_recall_cutoff(Y_train, nn_train_pred)
print('The optimal cutoff is', opt_cutoff)

## Changing likelihoods to labels
nn_test_label = np.where(nn_test_pred < opt_cutoff, 0, 1)

## Creating data-frame for submission
data_out = pd.DataFrame({'id': test_id, 'target': nn_test_label})
data_out.to_csv('network_submission_1.csv', index = False)
# Out:
# Epoch 1/20
# 191/191 [==============================] - 1s 4ms/step - loss: 0.6852 - accuracy: 0.5460 - val_loss: 0.6741 - val_accuracy: 0.5857
# Epoch 2/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6754 - accuracy: 0.5737 - val_loss: 0.6682 - val_accuracy: 0.6244
# Epoch 3/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6657 - accuracy: 0.6279 - val_loss: 0.6570 - val_accuracy: 0.6408
# Epoch 4/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6529 - accuracy: 0.6358 - val_loss: 0.6468 - val_accuracy: 0.6428
# Epoch 5/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6405 - accuracy: 0.6302 - val_loss: 0.6419 - val_accuracy: 0.6330
# Epoch 6/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6350 - accuracy: 0.6345 - val_loss: 0.6420 - val_accuracy: 0.6356
# Epoch 7/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6317 - accuracy: 0.6391 - val_loss: 0.6430 - val_accuracy: 0.6336
# Epoch 8/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6318 - accuracy: 0.6417 - val_loss: 0.6392 - val_accuracy: 0.6382
# Epoch 9/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6297 - accuracy: 0.6407 - val_loss: 0.6395 - val_accuracy: 0.6362
# Epoch 10/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6289 - accuracy: 0.6452 - val_loss: 0.6401 - val_accuracy: 0.6395
# Epoch 11/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6286 - accuracy: 0.6430 - val_loss: 0.6387 - val_accuracy: 0.6441
# Epoch 12/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6279 - accuracy: 0.6470 - val_loss: 0.6391 - val_accuracy: 0.6435
# Epoch 13/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6276 - accuracy: 0.6465 - val_loss: 0.6377 - val_accuracy: 0.6408
# Epoch 14/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6269 - accuracy: 0.6463 - val_loss: 0.6431 - val_accuracy: 0.6408
# Epoch 15/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6260 - accuracy: 0.6499 - val_loss: 0.6367 - val_accuracy: 0.6448
# Epoch 16/20
# 191/191 [==============================] - 1s 3ms/step - loss: 0.6246 - accuracy: 0.6435 - val_loss: 0.6360 - val_accuracy: 0.6467
# Epoch 17/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6234 - accuracy: 0.6519 - val_loss: 0.6353 - val_accuracy: 0.6487
# Epoch 18/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6231 - accuracy: 0.6521 - val_loss: 0.6360 - val_accuracy: 0.6481
# Epoch 19/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6212 - accuracy: 0.6527 - val_loss: 0.6374 - val_accuracy: 0.6520
# Epoch 20/20
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6209 - accuracy: 0.6558 - val_loss: 0.6393 - val_accuracy: 0.6527
# The optimal cutoff is 0.32612613

# %%
nn_pred
# Out:
# array([[0.7194805 , 0.28051952],
#        [0.6584695 , 0.3415305 ],
#        [0.6979774 , 0.3020226 ],
#        ...,
#        [0.35780114, 0.64219886],
#        [0.62765753, 0.37234244],
#        [0.5311666 , 0.46883336]], dtype=float32)

# %%
def precision_recall_cutoff(Y_test, Y_pred):
    
    ## Computing the precision recall curve
    precision, recall, thresholds = precision_recall_curve(Y_test, Y_pred)
    
    ## Creating the precision-recall data-frame
    precision_recall = pd.DataFrame({'precision': precision[:-1], 'recall': recall[:-1], 'cutoff': thresholds})
    
    ## Finding the optimal cutoff (closest to precision = 1, recall = 1)
    precision_recall['1_minus_precision'] = 1 - precision_recall['precision']
    precision_recall['1_minus_recall'] = 1 - precision_recall['recall']
    precision_recall['Distance_to_perfect_model'] = np.sqrt(precision_recall['1_minus_precision']**2 + precision_recall['1_minus_recall']**2)
    
    ## Sorting based on Distance 
    precision_recall = precision_recall.sort_values(by = 'Distance_to_perfect_model').reset_index(drop = True)
        
    return precision_recall['cutoff'][0]


logit_pred = logit_md.predict_(X)[:, 1]
opt_cutoff = precision_recall_cutoff(Y, logit_pred)
print('The optimal cutoff is', opt_cutoff)

## Predicting on test 
logit_test_pred = logit_md.predict_proba(test.drop(columns = ['id', 'keyword', 'text'], axis = 1))[:, 1]

## Changing likelihoods to labels
logit_test_label = np.where(logit_test_pred < opt_cutoff, 0, 1)

## Creating data-frame for submission
data_out = pd.DataFrame({'id': test['id'], 'target': logit_test_label})
data_out.to_csv('Logistic_submission_1.csv', index = False)

# %%
Y_test
# Out:
# 7092    0
# 145     1
# 6006    1
# 6937    0
# 2419    1
#        ..
# 2112    0
# 4728    0
# 5594    1
# 5142    0
# 6986    0
# Name: target, Length: 1523, dtype: int64

# %%
test.head()
# Out:
#    id keyword location                                               text  \
# 0   0       0        0                 Just happened a terrible car crash
# 1   2       0        0  Heard about #earthquake is different cities, s...
# 2   3       0        0  there is a forest fire at spot pond, geese are...
# 3   9       0        0           Apocalypse lighting. #Spokane #wildfires
# 4  11       0        0      Typhoon Soudelor kills 28 in China and Taiwan
#
#                                          clean_tweet  subjectivity  negative  \
# 0                        happened terrible car crash          1.00         1
# 1          heard different cities stay safe everyone          0.55         0
# 2  forest fire spot pond geese fleeing across str...          0.00         0
# 3                                apocalypse lighting          0.00         0
# 4             typhoon soudelor kills 28 china taiwan          0.00         0
#
#    neutral  positive  char_count  word_count  sent_count  capital_char_count  \
# 0        0         0          34           6           1                   1
# 1        0         1          64           9           1                   1
# 2        1         0          96          19           1                   1
# 3        1         0          40           4           2                   2
# 4        1         0          45           8           1                   4
#
#    capital_word_count  stopword_count  unique_word_count  avg_wordlength  \
# 0                   0               1                  6        5.666667
# 1                   0               2                  9        7.111111
# 2                   1              10                 19        5.052632
# 3                   0               0                  4       10.000000
# 4                   0               2                  8        5.625000
#
#    avg_sentlength  unique_vs_words  stopwords_vs_words
# 0             6.0              1.0            0.166667
# 1             9.0              1.0            0.222222
# 2            19.0              1.0            0.526316
# 3             2.0              1.0            0.000000
# 4             8.0              1.0            0.250000
