# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.multiclass import OneVsRestClassifier
import tensorflow as tf

train = pd.read_csv('train.csv')
train = train.fillna(0)

test = pd.read_csv('test.csv')
test = test.fillna(0)

test_id = test['id']
test = test.drop(columns = ['id', 'keyword', 'location', 'text', 'clean_tweet'], axis = 1)

## Defining input and target variables 
X = train.drop(columns = ['id', 'keyword', 'location', 'text', 'clean_tweet', 'target'], axis = 1)
Y = train['target']

## Splitting the data 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

## Scaling the data 
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
test = scaler.fit_transform(test)

## Defining model 
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(10, input_dim = 65, activation = 'relu'),
#         tf.keras.layers.Dense(10, activation = 'relu'),
        tf.keras.layers.Dense(2, activation = 'softmax')
])

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

## Fitting model 
model.fit(X_train, tf.keras.utils.to_categorical(Y_train, num_classes = 2), epochs = 50, batch_size = 32, validation_data = (X_test, tf.keras.utils.to_categorical(Y_test, num_classes = 2)))

## Predicting on train and test
nn_train_pred = model.predict(X_train)[:, 1]
nn_test_pred = model.predict(test)[:, 1]


def precision_recall_cutoff(Y_test, Y_pred):
    
    ## Computing the precision recall curve
    precision, recall, thresholds = precision_recall_curve(Y_test, Y_pred)
    
    ## Creating the precision-recall data-frame
    precision_recall = pd.DataFrame({'precision': precision[:-1], 'recall': recall[:-1], 'cutoff': thresholds})
    
    ## Finding the optimal cutoff (closest to precision = 1, recall = 1)
    precision_recall['1_minus_precision'] = 1 - precision_recall['precision']
    precision_recall['1_minus_recall'] = 1 - precision_recall['recall']
    precision_recall['Distance_to_perfect_model'] = np.sqrt(precision_recall['1_minus_precision']**2 + precision_recall['1_minus_recall']**2)
    
    ## Sorting based on Distance 
    precision_recall = precision_recall.sort_values(by = 'Distance_to_perfect_model').reset_index(drop = True)
        
    return precision_recall['cutoff'][0]

opt_cutoff = precision_recall_cutoff(Y_train, nn_train_pred)
print('The optimal cutoff is', opt_cutoff)

## Changing likelihoods to labels
nn_test_label = np.where(nn_test_pred < opt_cutoff, 0, 1)

## Creating data-frame for submission
data_out = pd.DataFrame({'id': test_id, 'target': nn_test_label})
# data_out.to_csv('network_submission_3.csv', index = False)
# Out:
# Epoch 1/50
# 191/191 [==============================] - 1s 2ms/step - loss: 0.6747 - accuracy: 0.5773 - val_loss: 0.6541 - val_accuracy: 0.6428
# Epoch 2/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.6373 - accuracy: 0.6470 - val_loss: 0.6239 - val_accuracy: 0.6717
# Epoch 3/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.6121 - accuracy: 0.6677 - val_loss: 0.6031 - val_accuracy: 0.6934
# Epoch 4/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5972 - accuracy: 0.6798 - val_loss: 0.5895 - val_accuracy: 0.6894
# Epoch 5/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5885 - accuracy: 0.6839 - val_loss: 0.5810 - val_accuracy: 0.6934
# Epoch 6/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5839 - accuracy: 0.6836 - val_loss: 0.5768 - val_accuracy: 0.6914
# Epoch 7/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5800 - accuracy: 0.6846 - val_loss: 0.5733 - val_accuracy: 0.6999
# Epoch 8/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5775 - accuracy: 0.6877 - val_loss: 0.5711 - val_accuracy: 0.6947
# Epoch 9/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5756 - accuracy: 0.6887 - val_loss: 0.5707 - val_accuracy: 0.6947
# Epoch 10/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5736 - accuracy: 0.6905 - val_loss: 0.5698 - val_accuracy: 0.6967
# Epoch 11/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5725 - accuracy: 0.6908 - val_loss: 0.5690 - val_accuracy: 0.6940
# Epoch 12/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5708 - accuracy: 0.6961 - val_loss: 0.5690 - val_accuracy: 0.6894
# Epoch 13/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5697 - accuracy: 0.6921 - val_loss: 0.5673 - val_accuracy: 0.6960
# Epoch 14/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5688 - accuracy: 0.6934 - val_loss: 0.5657 - val_accuracy: 0.6947
# Epoch 15/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5673 - accuracy: 0.6954 - val_loss: 0.5656 - val_accuracy: 0.6947
# Epoch 16/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5665 - accuracy: 0.6941 - val_loss: 0.5665 - val_accuracy: 0.6953
# Epoch 17/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5650 - accuracy: 0.6980 - val_loss: 0.5647 - val_accuracy: 0.7012
# Epoch 18/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5645 - accuracy: 0.6962 - val_loss: 0.5662 - val_accuracy: 0.6980
# Epoch 19/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5633 - accuracy: 0.6985 - val_loss: 0.5673 - val_accuracy: 0.6986
# Epoch 20/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5630 - accuracy: 0.6990 - val_loss: 0.5628 - val_accuracy: 0.6953
# Epoch 21/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5616 - accuracy: 0.7003 - val_loss: 0.5633 - val_accuracy: 0.6940
# Epoch 22/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5607 - accuracy: 0.7026 - val_loss: 0.5626 - val_accuracy: 0.6967
# Epoch 23/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5603 - accuracy: 0.7015 - val_loss: 0.5649 - val_accuracy: 0.6921
# Epoch 24/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5592 - accuracy: 0.7053 - val_loss: 0.5660 - val_accuracy: 0.7026
# Epoch 25/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5587 - accuracy: 0.7025 - val_loss: 0.5639 - val_accuracy: 0.6953
# Epoch 26/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5582 - accuracy: 0.7020 - val_loss: 0.5658 - val_accuracy: 0.6980
# Epoch 27/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5571 - accuracy: 0.7051 - val_loss: 0.5680 - val_accuracy: 0.7058
# Epoch 28/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5566 - accuracy: 0.7038 - val_loss: 0.5646 - val_accuracy: 0.6921
# Epoch 29/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5566 - accuracy: 0.7059 - val_loss: 0.5654 - val_accuracy: 0.6960
# Epoch 30/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5551 - accuracy: 0.7064 - val_loss: 0.5642 - val_accuracy: 0.6960
# Epoch 31/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5547 - accuracy: 0.7049 - val_loss: 0.5626 - val_accuracy: 0.6973
# Epoch 32/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5537 - accuracy: 0.7072 - val_loss: 0.5636 - val_accuracy: 0.6960
# Epoch 33/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5537 - accuracy: 0.7031 - val_loss: 0.5634 - val_accuracy: 0.7039
# Epoch 34/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5532 - accuracy: 0.7092 - val_loss: 0.5703 - val_accuracy: 0.7052
# Epoch 35/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5514 - accuracy: 0.7089 - val_loss: 0.5657 - val_accuracy: 0.7019
# Epoch 36/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5518 - accuracy: 0.7099 - val_loss: 0.5630 - val_accuracy: 0.7006
# Epoch 37/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5514 - accuracy: 0.7084 - val_loss: 0.5639 - val_accuracy: 0.7012
# Epoch 38/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5510 - accuracy: 0.7072 - val_loss: 0.5628 - val_accuracy: 0.6980
# Epoch 39/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5505 - accuracy: 0.7108 - val_loss: 0.5643 - val_accuracy: 0.6973
# Epoch 40/50
# 191/191 [==============================] - 0s 2ms/step - loss: 0.5496 - accuracy: 0.7069 - val_loss: 0.5647 - val_accuracy: 0.6980
# Epoch 41/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5496 - accuracy: 0.7085 - val_loss: 0.5651 - val_accuracy: 0.6953
# Epoch 42/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5489 - accuracy: 0.7089 - val_loss: 0.5633 - val_accuracy: 0.6967
# Epoch 43/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5485 - accuracy: 0.7103 - val_loss: 0.5638 - val_accuracy: 0.7032
# Epoch 44/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5480 - accuracy: 0.7092 - val_loss: 0.5651 - val_accuracy: 0.7039
# Epoch 45/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5472 - accuracy: 0.7097 - val_loss: 0.5638 - val_accuracy: 0.7012
# Epoch 46/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5485 - accuracy: 0.7102 - val_loss: 0.5659 - val_accuracy: 0.7012
# Epoch 47/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5454 - accuracy: 0.7108 - val_loss: 0.5675 - val_accuracy: 0.7032
# Epoch 48/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5466 - accuracy: 0.7113 - val_loss: 0.5651 - val_accuracy: 0.6993
# Epoch 49/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5465 - accuracy: 0.7120 - val_loss: 0.5658 - val_accuracy: 0.7039
# Epoch 50/50
# 191/191 [==============================] - 0s 1ms/step - loss: 0.5458 - accuracy: 0.7097 - val_loss: 0.5678 - val_accuracy: 0.7039
# The optimal cutoff is 0.35786572

# %%
data_out.to_csv('network_submission_3.csv', index = False)

# %%
data_out['target'].value_counts() / data_out.shape[0]
# Out:
# 1    0.517009
# 0    0.482991
# Name: target, dtype: float64

# %%
data_out['target'].value_counts() / data_out.shape[0]
# Out:
# 1    0.581673
# 0    0.418327
# Name: target, dtype: float64

# %%
Y.value_counts() / Y.shape[0]
# Out:
# 0    0.57034
# 1    0.42966
# Name: target, dtype: float64

# %%
X_train.shape
# Out:
# (6090, 65)

# %%
nn_pred
# Out:
# array([[0.7194805 , 0.28051952],
#        [0.6584695 , 0.3415305 ],
#        [0.6979774 , 0.3020226 ],
#        ...,
#        [0.35780114, 0.64219886],
#        [0.62765753, 0.37234244],
#        [0.5311666 , 0.46883336]], dtype=float32)

# %%
def precision_recall_cutoff(Y_test, Y_pred):
    
    ## Computing the precision recall curve
    precision, recall, thresholds = precision_recall_curve(Y_test, Y_pred)
    
    ## Creating the precision-recall data-frame
    precision_recall = pd.DataFrame({'precision': precision[:-1], 'recall': recall[:-1], 'cutoff': thresholds})
    
    ## Finding the optimal cutoff (closest to precision = 1, recall = 1)
    precision_recall['1_minus_precision'] = 1 - precision_recall['precision']
    precision_recall['1_minus_recall'] = 1 - precision_recall['recall']
    precision_recall['Distance_to_perfect_model'] = np.sqrt(precision_recall['1_minus_precision']**2 + precision_recall['1_minus_recall']**2)
    
    ## Sorting based on Distance 
    precision_recall = precision_recall.sort_values(by = 'Distance_to_perfect_model').reset_index(drop = True)
        
    return precision_recall['cutoff'][0]


logit_pred = logit_md.predict_(X)[:, 1]
opt_cutoff = precision_recall_cutoff(Y, logit_pred)
print('The optimal cutoff is', opt_cutoff)

## Predicting on test 
logit_test_pred = logit_md.predict_proba(test.drop(columns = ['id', 'keyword', 'text'], axis = 1))[:, 1]

## Changing likelihoods to labels
logit_test_label = np.where(logit_test_pred < opt_cutoff, 0, 1)

## Creating data-frame for submission
data_out = pd.DataFrame({'id': test['id'], 'target': logit_test_label})
data_out.to_csv('Logistic_submission_1.csv', index = False)

# %%
Y_test
# Out:
# 7092    0
# 145     1
# 6006    1
# 6937    0
# 2419    1
#        ..
# 2112    0
# 4728    0
# 5594    1
# 5142    0
# 6986    0
# Name: target, Length: 1523, dtype: int64

# %%
test.head()
# Out:
#    id keyword location                                               text  \
# 0   0       0        0                 Just happened a terrible car crash
# 1   2       0        0  Heard about #earthquake is different cities, s...
# 2   3       0        0  there is a forest fire at spot pond, geese are...
# 3   9       0        0           Apocalypse lighting. #Spokane #wildfires
# 4  11       0        0      Typhoon Soudelor kills 28 in China and Taiwan
#
#                                          clean_tweet  subjectivity  negative  \
# 0                        happened terrible car crash          1.00         1
# 1          heard different cities stay safe everyone          0.55         0
# 2  forest fire spot pond geese fleeing across str...          0.00         0
# 3                                apocalypse lighting          0.00         0
# 4             typhoon soudelor kills 28 china taiwan          0.00         0
#
#    neutral  positive  char_count  word_count  sent_count  capital_char_count  \
# 0        0         0          34           6           1                   1
# 1        0         1          64           9           1                   1
# 2        1         0          96          19           1                   1
# 3        1         0          40           4           2                   2
# 4        1         0          45           8           1                   4
#
#    capital_word_count  stopword_count  unique_word_count  avg_wordlength  \
# 0                   0               1                  6        5.666667
# 1                   0               2                  9        7.111111
# 2                   1              10                 19        5.052632
# 3                   0               0                  4       10.000000
# 4                   0               2                  8        5.625000
#
#    avg_sentlength  unique_vs_words  stopwords_vs_words
# 0             6.0              1.0            0.166667
# 1             9.0              1.0            0.222222
# 2            19.0              1.0            0.526316
# 3             2.0              1.0            0.000000
# 4             8.0              1.0            0.250000
